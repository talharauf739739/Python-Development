# %%
# !pip install selenium
import pandas as pd
import re
import time
import selenium
#from selenium.webdriver.common.keys import keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
# !pip install requests
# !pip install beautifulsoup4

# !pip install requests

from bs4 import BeautifulSoup
import requests
import pandas as pd 
import requests
# Out:
# Requirement already satisfied: selenium in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (4.7.1)
# Requirement already satisfied: trio~=0.17 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: async-generator>=1.9 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: sniffio in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: requests in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: requests in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h.a.r\anaconda3\envs\kr\lib\site-packages (from requests) (2022.9.14)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument("--test-type")   
options.binary_location = r"C:/Program Files/Google/Chrome/Application/chrome.exe"
chrome_driver_binary = r"C:/Users/H.A.R/AppData/Roaming/Microsoft/Windows/Start Menu/Programs/Anaconda3 (64-bit)/chromedriver.exe"
driver = webdriver.Chrome(chrome_driver_binary, chrome_options=options)
driver.get('https://www.google.com/')
# Out:
# C:\Users\H.A.R\AppData\Local\Temp\ipykernel_8188\1693127414.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_binary, chrome_options=options)
# C:\Users\H.A.R\AppData\Local\Temp\ipykernel_8188\1693127414.py:9: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_driver_binary, chrome_options=options)

# %%
import time
from time import sleep
geography_search_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input")
require_data = geography_search_bar.send_keys('pediatrician florida linkedIn "gmail"')
sleep(2)


#/html/body/div[1]/div[3]/form/div[1]/div[1]/div[4]/center/input[1]
google_search_button = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[4]/center/input[1]")
google_search_button.click()

# %%
# maximize window
driver.maximize_window()

# %%
from time import sleep

# Getting the Current URL
first_page_url = driver.current_url 
print(first_page_url)
sleep(1)
##############
# get request
response = requests.get(first_page_url)
sleep(1)
#Status Code,  Getting the Access from desire Website
response.status_code

sleep(1)
# soup object lxml
soup = BeautifulSoup(response.content, 'html.parser')
#soup = BeautifulSoup(response.content, 'lxml')
soup
# Out:
# https://www.google.com/search?q=pediatrician+florida+linkedIn+%22gmail%22pediatrician+florida+linkedIn+%22gmail%22&source=hp&ei=fbKkY9fjBviDkdUP5uK4mAI&iflsig=AJiK0e8AAAAAY6TAjXUJXCZtMxK9ue-eJmFjqnQ-qeXy&ved=0ahUKEwiXlpak_Y38AhX4QaQEHWYxDiMQ4dUDCA0&oq=pediatrician+florida+linkedIn+%22gmail%22pediatrician+florida+linkedIn+%22gmail%22&gs_lcp=Cgdnd3Mtd2l6EAw6BQghEKABUABY75QCYMalAmgAcAB4BIABkQOIAewWkgEFMy02LjKYAQCgAQE&sclient=gws-wiz
# <!DOCTYPE html>
# <html lang="en-PK"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>pediatrician florida linkedIn "gmail"pediatrician florida linkedIn "gmail" - Google Search</title><script nonce="tHFS5DmIbhm-4gaulX68Kg">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){var a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};var h=function(g){g&&g.target.setAttribute("data-iml",String(Date.now()))};document.documentElement.addEventListener("load",h,!0);google.rglh=function(){document.documentElement.removeEventListener("load",h,!0)};}).call(this);(function(){window._skwEvts=[];})();(function(){window.google.erd={jsr:1,bv:1702,de:true};})();(function(){var sdo=false;var mei=10;
# var h=this||self;var k,l=null!=(k=h.mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml=function(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);if(google.dl)return google.dl(a,e,d),null;if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||q>=l&&!m?!1:!0;if(!b)return null;q++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(t.jsr)+"&bver="+b(t.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=
# a.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));c+="&jsel="+e;for(var u in d)c+="&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.log(0,"",a);return a};window.onerror=function(a,b,d,m,e){r!==a&&(a=e instanceof Error?e:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("Script error")?3:0));r=null;p&&q>=l&&(window.onerror=null)};})();(function(){var c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+Date.now());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};}).call(this);</script><style>a{color:#1a0dab;text-decoration:none;tap-highlight-color:rgba(0,0,0,.10)}a:visited{color:#4b11a8}a:hover{text-decoration:underline}img{border:0}html{font-family:arial,sans-serif;font-size:14px;line-height:20px;text-size-adjust:100%;color:#3c4043;word-wrap:break-word;background-color:#fff}.bRsWnc{background-color:#fff;border-top:1px solid #dadce0;height:39px;overflow:hidden}.N6RWV{height:51px;overflow-scrolling:touch;overflow-x:auto;overflow-y:hidden}.Uv67qb{box-pack:justify;font-size:12px;line-height:37px;justify-content:space-between;justify-content:space-between}.Uv67qb a,.Uv67qb span{color:#70757a;display:block;flex:none;padding:0 16px;text-align:center;text-transform:uppercase;}span.OXXup{border-bottom:2px solid #4285f4;color:#4285f4;font-weight:bold}a.eZt8xd:visited{color:#70757a}.FElbsf{border-left:1px solid rgba(0,0,0,.12)}header article{overflow:visible}.Pg70bf{height:39px;display:box;display:flex;display:flex;width:100%}.H0PQec{position:relative;flex:1}.sbc{display:flex;width:100%}.Pg70bf input{margin:2px 4px 2px 8px;}.x{width:26px;color:#70757a;font:27px/38px arial, sans-serif;line-height:40px;}#qdClwb{flex:0 0 auto;width:39px;height:39px;border-bottom:0;padding:0;border-top-right-radius:8px;background-color:#1a73e8;border:1px solid #1a73e8;background-image:url(...);}.sc{font-size:16px;position:absolute;top:39px;left:0;right:0;box-shadow:0 2px 5px rgba(0,0,0,.2);z-index:2;background-color:#fff}.sc>div{padding:10px 10px;padding-left:16px;padding-left:14px;border-top:1px solid #dfe1e5;}.scs{background-color:#fafafa;}.noHIxc{display:block;font-size:16px;padding:0 0 0 8px;flex:1;height:35px;outline:none;border:none;width:100%;-webkit-tap-highlight-color:rgba(0,0,0,0);overflow:hidden;}.sbc input[type=text]{background:none}.bz1lBb{background-color:#fff;border-radius:8px 8px 0 0;box-shadow:0 0 0 1px #dfe1e5;margin-top:24px;}.KP7LCb{border-radius:0 0 8px 8px;box-shadow:0px 1px 0px 1px #dfe1e5;margin-bottom:30px;overflow:hidden}html{background-color:#fff}body{margin:0 auto 0 156px;max-width:652px;min-width:652px;padding:0 8px}.cOl4Id{letter-spacing:-1px;text-align:center;font:22pt Futura, Arial, sans-serif;height:37px;font-smoothing:antialiased;padding:32px 28px 0 24px;position:absolute;left:0;top:0}.cOl4Id span{display:inline-block}.V6gwVd{color:#4285f4}.iWkuvd{color:#ea4335}.cDrQ7{color:#fcc934}.ntlR9{color:#34a853}.tJ3Myc{-webkit-transform:rotate(-20deg);position:relative;left:-1px;display:inline-block}footer{text-align:center;margin-top:18px}footer a,footer a:visited,.smiUbb{color:#70757a}.xeDNfc{margin:0 13px;white-space:nowrap}#EOlPnc{margin-top:36px}#EOlPnc>div{margin:20px}.Srfpq{color:#70757a}</style></head><body jsmodel="hspDDf"><header id="hdr"><script nonce="tHFS5DmIbhm-4gaulX68Kg">(function(){
# var k=this||self,l=function(a){var b=typeof a;return"object"==b&&null!=a||"function"==b},m=function(a,b){function c(){}c.prototype=b.prototype;a.j=b.prototype;a.prototype=new c;a.prototype.constructor=a;a.l=function(d,e,f){for(var g=Array(arguments.length-2),h=2;h<arguments.length;h++)g[h-2]=arguments[h];return b.prototype[e].apply(d,g)}};var n=Array.prototype.indexOf?function(a,b){return Array.prototype.indexOf.call(a,b,void 0)}:function(a,b){if("string"===typeof a)return"string"!==typeof b||1!=b.length?-1:a.indexOf(b,0);for(var c=0;c<a.length;c++)if(c in a&&a[c]===b)return c;return-1};var p=function(a){return"string"==typeof a.className?a.className:a.getAttribute&&a.getAttribute("class")||""},q=function(a,b){"string"==typeof a.className?a.className=b:a.setAttribute&&a.setAttribute("class",b)},r=function(a,b){a.classList?b=a.classList.contains(b):(a=a.classList?a.classList:p(a).match(/\S+/g)||[],b=0<=n(a,b));return b},v=function(){var a=t,b=u;a.classList?a.classList.remove(b):r(a,b)&&q(a,Array.prototype.filter.call(a.classList?a.classList:p(a).match(/\S+/g)||[],function(c){return c!=
# b}).join(" "))};function w(){var a=k.navigator;return a&&(a=a.userAgent)?a:""};var x=function(a){x[" "](a);return a};x[" "]=function(){};var y=-1!=w().indexOf("Gecko")&&!(-1!=w().toLowerCase().indexOf("webkit")&&-1==w().indexOf("Edge"))&&!(-1!=w().indexOf("Trident")||-1!=w().indexOf("MSIE"))&&-1==w().indexOf("Edge");var z=function(a,b){this.type=a;this.target=b};z.prototype.g=function(){};var A=function(){if(!k.addEventListener||!Object.defineProperty)return!1;var a=!1,b=Object.defineProperty({},"passive",{get:function(){a=!0}});try{k.addEventListener("test",function(){},b),k.removeEventListener("test",function(){},b)}catch(c){}return a}();var C=function(a){z.call(this,a?a.type:"");this.relatedTarget=this.target=null;this.button=this.screenY=this.screenX=this.clientY=this.clientX=0;this.key="";this.keyCode=0;this.metaKey=this.shiftKey=this.altKey=this.ctrlKey=!1;this.state=null;this.pointerId=0;this.pointerType="";this.h=null;if(a){var b=this.type=a.type,c=a.changedTouches&&a.changedTouches.length?a.changedTouches[0]:null;this.target=a.target||a.srcElement;var d=a.relatedTarget;if(d){if(y){a:{try{x(d.nodeName);var e=!0;break a}catch(f){}e=
# !1}e||(d=null)}}else"mouseover"==b?d=a.fromElement:"mouseout"==b&&(d=a.toElement);this.relatedTarget=d;c?(this.clientX=void 0!==c.clientX?c.clientX:c.pageX,this.clientY=void 0!==c.clientY?c.clientY:c.pageY,this.screenX=c.screenX||0,this.screenY=c.screenY||0):(this.clientX=void 0!==a.clientX?a.clientX:a.pageX,this.clientY=void 0!==a.clientY?a.clientY:a.pageY,this.screenX=a.screenX||0,this.screenY=a.screenY||0);this.button=a.button;this.keyCode=a.keyCode||0;this.key=a.key||"";this.ctrlKey=a.ctrlKey;this.altKey=a.altKey;this.shiftKey=a.shiftKey;this.metaKey=a.metaKey;this.pointerId=a.pointerId||0;this.pointerType="string"===typeof a.pointerType?a.pointerType:B[a.pointerType]||"";this.state=a.state;this.h=a;a.defaultPrevented&&C.j.g.call(this)}};m(C,z);var B={2:"touch",3:"pen",4:"mouse"};C.prototype.g=function(){C.j.g.call(this);var a=this.h;a.preventDefault?a.preventDefault():a.returnValue=!1};var D="closure_listenable_"+(1E6*Math.random()|0);var E=0;var F=function(a,b,c,d,e){this.listener=a;this.proxy=null;this.src=b;this.type=c;this.capture=!!d;this.h=e;this.key=++E;this.g=this.i=!1},G=function(a){a.g=!0;a.listener=null;a.proxy=null;a.src=null;a.h=null};var H=function(a){this.src=a;this.g={};this.h=0};H.prototype.add=function(a,b,c,d,e){var f=a.toString();a=this.g[f];a||(a=this.g[f]=[],this.h++);var g;a:{for(g=0;g<a.length;++g){var h=a[g];if(!h.g&&h.listener==b&&h.capture==!!d&&h.h==e)break a}g=-1}-1<g?(b=a[g],c||(b.i=!1)):(b=new F(b,this.src,f,!!d,e),b.i=c,a.push(b));return b};var I="closure_lm_"+(1E6*Math.random()|0),J={},K=0,M=function(a,b,c,d,e){if(d&&d.once)return L(a,b,c,d,e);if(Array.isArray(b)){for(var f=0;f<b.length;f++)M(a,b[f],c,d,e);return null}c=N(c);return a&&a[D]?a.g(b,c,l(d)?!!d.capture:!!d,e):O(a,b,c,!1,d,e)},O=function(a,b,c,d,e,f){if(!b)throw Error("a");var g=l(e)?!!e.capture:!!e,h=P(a);h||(a[I]=h=new H(a));c=h.add(b,c,d,g,f);if(c.proxy)return c;d=Q();c.proxy=d;d.src=a;d.listener=c;if(a.addEventListener)A||(e=g),void 0===e&&(e=!1),a.addEventListener(b.toString(),d,e);else if(a.attachEvent)a.attachEvent(R(b.toString()),d);else if(a.addListener&&a.removeListener)a.addListener(d);else throw Error("b");K++;return c},Q=function(){var a=S,b=function(c){return a.call(b.src,b.listener,c)};return b},L=function(a,b,c,d,e){if(Array.isArray(b)){for(var f=0;f<b.length;f++)L(a,b[f],c,d,e);return null}c=N(c);return a&&a[D]?a.h(b,c,l(d)?!!d.capture:!!d,e):O(a,b,c,!0,d,e)},T=function(a){if("number"!==typeof a&&a&&!a.g){var b=a.src;if(b&&b[D])b.o(a);else{var c=a.type,d=a.proxy;b.removeEventListener?b.removeEventListener(c,d,a.capture):b.detachEvent?b.detachEvent(R(c),d):b.addListener&&b.removeListener&&b.removeListener(d);K--;if(c=P(b)){d=a.type;if(d in c.g){var e=c.g[d],f=n(e,a),g;(g=0<=f)&&Array.prototype.splice.call(e,f,1);g&&(G(a),0==c.g[d].length&&(delete c.g[d],c.h--))}0==c.h&&(c.src=null,b[I]=null)}else G(a)}}},R=function(a){return a in J?J[a]:J[a]="on"+a},S=function(a,b){if(a.g)a=!0;else{b=new C(b,this);var c=a.listener,d=a.h||a.src;a.i&&T(a);a=c.call(d,b)}return a},P=function(a){a=a[I];return a instanceof H?a:null},U="__closure_events_fn_"+(1E9*Math.random()>>>0),N=function(a){if("function"===typeof a)return a;a[U]||(a[U]=function(b){return a.handleEvent(b)});return a[U]};var u,t=document.documentElement,V;function W(){T(V);V=L(t,"mousedown",function(){v();X()},{capture:!0})}function X(){T(V);V=M(t,"keydown",function(a){if(9===a.keyCode){a=t;var b=u;if(a.classList)a.classList.add(b);else if(!r(a,b)){var c=p(a);q(a,c+(0<c.length?" "+b:b))}W()}})};u="zAoYTe";X();}).call(this);</script><div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwjdgMi7_Y38AhVIG7cAHT-gAEQQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div><div class="bz1lBb"><form class="Pg70bf" id="sf"><input name="ie" type="hidden" value="ISO-8859-1"/><div class="H0PQec"><div class="sbc esbc"><input autocapitalize="none"  ...
# var f=this||self,g=function(a){return a};var h,k=function(){if(void 0===h){var a=null,b=f.trustedTypes;if(b&&b.createPolicy){try{a=b.createPolicy("goog#html",{createHTML:g,createScript:g,createScriptURL:g})}catch(c){f.console&&f.console.error(c.message)}h=a}else h=a}return h};var p=function(a,b){this.h=a===l&&b||"";this.g=m},q=function(a){return a instanceof p&&a.constructor===p&&a.g===m?a.h:"type_error:Const"},m={},l={};var t=function(a,b){this.g=b===r?a:""};t.prototype.toString=function(){return this.g+""};var u=function(a){return a instanceof t&&a.constructor===t?a.g:"type_error:TrustedResourceUrl"},y=function(){var a={},b=q(new p(l,"/complete/search"));if(!v.test(b))throw Error("a`"+b);var c=b.replace(w,function(e,d){if(!Object.prototype.hasOwnProperty.call(a,d))throw Error("b`"+d+"`"+b+"`"+JSON.stringify(a));e=a[d];return e instanceof p?q(e):encodeURIComponent(String(e))});return x(c)},w=/%{(\w+)}/g,v=RegExp("^((https:)?//[0-9a-z.:[\\]-]+/|/[^/\\\\]|[^:/\\\\%]+/|[^:/\\\\%]*[?#]|about:blank#)","i"),z=/^([^?#]*)(\?[^#]*)?(#[\s\S]*)?/,r={},x=function(a){var b=k();a=b?b.createScriptURL(a):a;return new t(a,r)},A=function(a,b,c){if(null==c)return b;if("string"===typeof c)return c?a+encodeURIComponent(c):"";for(var e in c)if(Object.prototype.hasOwnProperty.call(c,e)){var d=c[e];d=Array.isArray(d)?d:[d];for(var n=0;n<d.length;n++){var P=d[n];null!=P&&(b||(b=a),b+=(b.length>a.length?"&":"")+encodeURIComponent(e)+"="+encodeURIComponent(String(P)))}}return b};var B={},C=function(a,b){this.g=b===B?a:""};C.prototype.toString=function(){return this.g.toString()};var D=function(a){var b=k();a=b?b.createHTML(a):a;return new C(a,B)};
# function E(a,b){if(void 0!==a.tagName){if("script"===a.tagName.toLowerCase())throw Error("c");if("style"===a.tagName.toLowerCase())throw Error("d");}a.innerHTML=b instanceof C&&b.constructor===C?b.g:"type_error:SafeHtml"};var F=document.querySelector(".l"),G=document.querySelector("#sf"),H=G.querySelector(".sbc"),I=G.querySelector("[type=text]"),J=G.querySelector("[type=submit]"),K=G.querySelector(".sc"),L=G.querySelector(".x"),M=I.value,N=[],O=-1,Q=M,R,S,T;M||(L&&(L.style.display="none"),U(!1));function U(a){if(H.classList.contains("esbc")){var b=H.classList.contains("chsbc"),c=H.classList.contains("rtlsbc");a&&(K.style.display="block",b?(G.style.borderRadius="20px 20px 0 0",K.style.borderBottom="1px solid #DFE1E5",J.style.borderRadius=c?"20px 0 0 0":"0 20px 0 0"):H.style.borderRadius=c?"0 8px 0 0":"8px 0 0 0");a||(K.style.display="none",b?(G.style.borderRadius="20px",K.style.borderBottom="none",J.style.borderRadius=c?"20px 0 0 20px":"0 20px 20px 0"):H.style.borderRadius=c?"0 8px 8px 0":"8px 0 0 8px")}}function V(){G.querySelector("[name=oq]").value=Q;G.querySelector("[name=aqs]").value="heirloom-srp."+(0<=O?O:"")+"."+(0<N.length?"0l"+N.length:"")}
# function W(){R=null;if(S){var a={client:"heirloom-srp",hl:hl,json:"t",callback:"hS",q:S};"undefined"!==typeof ds&&ds&&(a.ds=ds);var b=document;var c="SCRIPT";"application/xhtml+xml"===b.contentType&&(c=c.toLowerCase());c=b.createElement(c);b=y();b=z.exec(u(b).toString());var e=b[3]||"";a=x(b[1]+A("?",b[2]||"",a)+A("#",e));c.src=u(a);var d,n;(d=(a=null==(n=(d=(c.ownerDocument&&c.ownerDocument.defaultView||window).document).querySelector)?void 0:n.call(d,"script[nonce]"))?a.nonce||a.getAttribute("nonce")||
# "":"")&&c.setAttribute("nonce",d);document.body.appendChild(c);S=null;R=setTimeout(W,500)}}function X(){for(;K.firstChild;)K.removeChild(K.firstChild);N=[];O=-1;U(!1)}function Y(){var a=K.querySelector(".scs");a&&(a.className="");0<=O?(a=K.childNodes[O],a.className="scs",M=a.textContent):M=Q;I.value=M}I.addEventListener("focus",function(){F&&(F.style.display="none")},!1);I.addEventListener("blur",function(){X();F&&(F.style.display="")},!1);I.addEventListener("keyup",function(a){M=I.value;T=!1;13===a.which?V():27===a.which?(X(),F&&(F.style.display=""),M=Q,I.value=M):40===a.which?(O++,O>=N.length&&(O=-1),Y()):38===a.which?(O--,-1>O&&(O=N.length-1),Y()):(a=M)?(L&&(L.style.display=""),S=a,R||W(),Q=a):(L&&(L.style.display="none"),U(!1),X(),Q="",T=!0)},!1);J.addEventListener("click",V,!1);L.addEventListener("click",function(){I.value="";L.style.display="none";U(!1)},!1);H.addEventListener("click",function(){I.focus()},!1);window.hS=function(a){if(!T){X();0===a[1].length&&U(!1);for(var b=0;b<a[1].length;b++){var c=a[1][b][0],e=document.createElement("div");E(e,D(c));e.addEventListener("mousedown",function(d){d.preventDefault();return!1},!1);c=c.replace(/<\/?b>/g,"");e.addEventListener("click",function(d){return function(){O=d;V();Y();X();G.submit()}}(b),!1);e.addEventListener("mouseover",function(d){return function(){O!==d&&(O=d,Y())}}(b),!1);K.appendChild(e);U(!0);N.push(c)}}};}).call(this);})();(function(){function b(a){for(a=a.target||a.srcElement;a&&"A"!==a.nodeName;)a=a.parentElement;a&&(a.href||"").match(/\/search.*[?&]tbm=isch/)&&(a.href+="&biw="+document.documentElement.clientWidth,a.href+="&bih="+document.documentElement.clientHeight)}document.addEventListener("click",b,!1);document.addEventListener("touchStart",b,!1);}).call(this);</script></div><!-- cctlcm 5 cctlcm --><textarea class="csi" name="csi" style="display:none"></textarea><script nonce="tHFS5DmIbhm-4gaulX68Kg">(function(){var e='rrKkY93xCci23LUPv8CCoAQ';var sn='web';var timl=false;var gecoh=true;var fil=true;(function(){function B(a){var b=gecoh;if(!a||C(a))return 0;if(!a.getBoundingClientRect)return 1;var c=function(d){return d.getBoundingClientRect()};return D(a,c,b)?0:J(a,c)}function D(a,b,c){a:{for(var d=a;d&&null!==d;d=d.parentElement)if("hidden"===d.style.overflow||c&&"G-EXPANDABLE-CONTENT"===d.tagName&&"hidden"===getComputedStyle(d).getPropertyValue("overflow")){c=d;break a}c=null}if(!c)return!1;a=b(a);b=b(c);return a.bottom<b.top||a.top>=b.bottom||a.right<b.left||a.left>=b.right}
# function C(a){return"none"===a.style.display?!0:document.defaultView&&document.defaultView.getComputedStyle?(a=document.defaultView.getComputedStyle(a),!!a&&("hidden"===a.visibility||"0px"===a.height&&"0px"===a.width)):!1}
# function J(a,b){var c=b(a);a=c.left+window.pageXOffset;b=c.top+window.pageYOffset;var d=c.width;c=c.height;var g=0;if(0>=c&&0>=d)return g;var q=window.innerHeight||document.documentElement.clientHeight;0>b+c?g=2:b>=q&&(g=4);if(0>a+d||a>=(window.innerWidth||document.documentElement.clientWidth))g|=8;g||(g=1,b+c>q&&(g|=4));return g};var K=e,L=sn,M="undefined"===typeof de?!0:!1!==de,N=[],O="undefined"!==typeof fil?fil:!1;function P(a,b,c){a="/gen_204?atyp=csi&s="+L+"&t="+a+("&lite=1&ei="+K+"&conn="+(window.navigator&&window.navigator.connection?window.navigator.connection.type:-1)+b);b="&rt=";for(var d in c)a+=""+b+d+"."+c[d],b=",";return a}function Q(a){a={prt:a};window.wsrt&&(a.wsrt=window.wsrt);return a}function R(a){window.ping?window.ping(a):(new Image).src=a}
# (function(){for(var a=(new Date).getTime()-window.start,b=Q(a),c=0,d=0,g=0,q=document.getElementsByTagName("img"),r=M?"&biw="+window.innerWidth+"&bih="+window.innerHeight:"",E=function(){r+="&ima="+g;b.aft=c;R(P("aft",r,b))},x=0,S=function(h,t,u){var n=h.src;h.onload=function(){u&&n&&n===h.src||(d=(new Date).getTime()-window.start,t&&++x===g&&(c=d,E()),h.onload=null)}},T=0,f=void 0;f=q[T++];){var v=B(f),p=!!(v&1);p&&++g;var l=f.hasAttribute("data-ilite"),w=f.hasAttribute("data-deferred"),F=f.hasAttribute("data-src")||
# f.hasAttribute("data-lzysrc"),y=!w&&!l&&F;N.push([v,w||l,y,!!(google.ldi&&f.id&&google.ldi[f.id])||l&&F]);l=(v=f.complete&&!w&&!(p&&y))&&Number(f.getAttribute("data-iml"))||0;v&&l?(p&&++x,l&&(f=l-window.start,p&&(c=Math.max(c,f)),d=Math.max(d,f))):S(f,p,O&&(w||y))}c||(c=a);d||(d=c);x===g&&E();google.rglh&&google.rglh();window.addEventListener("load",function(){window.setTimeout(function(){b.ol=(new Date).getTime()-window.start;timl&&(b.iml=d);var h=window.performance&&window.performance.timing;h&&
# (b.rqst=h.responseEnd-h.requestStart,b.rspt=h.responseEnd-h.responseStart);for(var t=h=0,u=0,n=0,G=0,H=0,U=0,k;k=N[U++];){var m=k[0],z=k[1],I=k[2];k=k[3];var V=0==m,W=m&8,A=m&1;m=!A&&m&4;A&&(z&&!k||++u,I&&++H);z&&(A&&k&&++h,m&&!k&&++t);V||W?I||++G:z||++n}r+="&ime="+u+"&imel="+H+("&imex="+n+"&imeh="+G)+("&imea="+h+"&imeb="+t);R(P("all",r,b))},0)},!1)})();}).call(this);})();</script><script nonce="tHFS5DmIbhm-4gaulX68Kg">(function(){var e='rrKkY93xCci23LUPv8CCoAQ';(function(){var a=e;2===(window.performance&&window.performance.navigation&&window.performance.navigation.type)&&window.ping("/gen_204?ct=backbutton&ei="+a);}).call(this);})();(function(){var b=[function(){google.tick&&google.tick("load","dcl")}];google.dclc=function(a){b.length?b.push(a):a()};function c(){for(var a=b.shift();a;)a(),a=b.shift()}window.addEventListener?(document.addEventListener("DOMContentLoaded",c,!1),window.addEventListener("load",c,!1)):window.attachEvent&&window.attachEvent("onload",c);}).call(this);window.jsl=window.jsl||{};window.jsl.dh=function(a,b,f){try{var g=document.getElementById(a);if(g)g.innerHTML=b,f&&f();else{var c={id:a,script:String(!!f),milestone:String(google.jslm||0)};google.jsla&&(c.async=google.jsla);var h=a.indexOf("_"),d=0<h?a.substring(0,h):"",k=document.createElement("div");k.innerHTML=b;var e=k.children[0];if(e&&(c.tag=e.tagName,c["class"]=String(e.className||null),c.name=String(e.getAttribute("jsname")),d)){a=[];var l=document.querySelectorAll('[id^="'+d+'_"]');for(b=0;b<l.length;++b)a.push(l[b].id);c.ids=a.join(",")}google.ml(Error(d?"Missing ID with prefix "+d:"Missing ID"),!1,c)}}catch(m){google.ml(m,!0,{"jsl.dh":!0})}};(function(){var x=false;google.jslm=x?2:1;})();(function(){(function(){google.csct={};google.csct.ps='AOvVaw1326Ww_ZCIWEN5t1cccFdh\x26ust\x3d1671824430200579';})();})();(function(){(function(){google.csct.rd=true;})();})();(function(){(function(){google.csct.rl=true;})();})();google.drty&&google.drty(undefined,true);</script></body></html>

# %% [markdown]
# # Scrolling

# %%
from time import sleep
def scrolling():
    
    
    new_scroll =driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    
    new_scroll

"""
for i in range(7):
    pre_scroll = driver.find_element(By.CSS_SELECTOR, 'html')
    #pre_scroll = driver.find_element(By.TAG_NAME, 'body')
    #pre_scroll.click()
    new_scroll = pre_scroll.send_keys(Keys.PAGE_DOWN)
    #new_scroll =driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        
    time.sleep(2)
    while True:
        new_scroll
        time.sleep(2)
        if new_scroll == pre_scroll:
            break
        pre_scroll = new_scroll
"""
# Out:
# '\nfor i in range(7):\n    pre_scroll = driver.find_element(By.CSS_SELECTOR, \'html\')\n    #pre_scroll = driver.find_element(By.TAG_NAME, \'body\')\n    #pre_scroll.click()\n    new_scroll = pre_scroll.send_keys(Keys.PAGE_DOWN)\n    #new_scroll =driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")\n        \n    time.sleep(2)\n    while True:\n        new_scroll\n        time.sleep(2)\n        if new_scroll == pre_scroll:\n            break\n        pre_scroll = new_scroll\n'

# %% [markdown]
# # Pagination

# %%
import time
from time import sleep

def pagination():
    next_button = driver.find_element(By.ID,"pnnext")
    next_button.click()
    sleep(3)

# %%
Title = []
Email = []
Link = []

def data_extraction():
    page_source = BeautifulSoup(driver.page_source)
    results = page_source.find_all('div', {'class' : 'MjjYud'})
    len(results)
    for result in results:
        
        scrolling()
    
    
        page_source = BeautifulSoup(driver.page_source)
        #Doctor Name
        person_title = result.find_all('div',class_='yuRUbf')
        try:
            name = person_title[0].find('h3').get_text()
            print(name)
            Title.append(name)
            sleep(2)
        
        except:
            no_name = print('Null')
            Title.append(no_name)
    
    
    
    
        person_link = result.find_all('div',class_='yuRUbf')
        try:
            website = person_link[0].find('a', href=True)
            personal_site = (website['href'])
            #persons_mail = mail[0].get()
            print(personal_site)
            Link.append(personal_site)
            sleep(2)
        except:
            no_link = print('https:www.linkedIn.com')
            Link.append(no_link)
    
    
        email_stuff = result.find_all('div', class_ = 'VwiC3b yXK7lf MUxGbd yDYNvb lyLwlc lEBKkf')
        try:
            person_email = email_stuff[0].find('span').get_text()
            print(person_email)
            Email.append(person_email)
        except:
            no_mail = print('no email found')
            Email.append(no_mail)
    
    
    
    #Calling Pagination

# %%
for i in range(16):
    data_extraction()
    pagination()
# Out:
# Harry Cuevas - MD - Kidsville Pediatrics
# https://www.linkedin.com/in/harry-cuevas-44955975
# Harry R. Cuevas Bocanegra, M.D. 05/23 Santurce, Puerto Rico 13546 Fordwell dr, Orlando, Fl 32828. Mob. 407-951-4329. Email: harcue@gmail.com. EDUCATION:
# Isabella Clem - Medical Assistant - Milestones Pediatrics, PC
# https://www.linkedin.com/in/isabella-clem
# Isabella is adaptable, empathetic, diligent, and hard-working. It is best that you contact her via email: clemisabella454@gmail.com. Activity.
# Catherine Limperopoulos' Post
# https://www.linkedin.com/posts/catherine-limperopoulos-0a77a596_research-pediatric-congenital-activity-6963865465899126785-v0Gc
# Join the Children's National Hospital Prenatal Pediatrics Institute team! ... Please send me a message or e-mail your CV to arianne.graham@gmail.com.
# Leigh Bouskila, MHA'S Post
# https://www.linkedin.com/posts/leighbouskila_please-join-us-for-this-exciting-opportunity-activity-6975432799684071427-4Eel?trk=public_profile_like_view
# Improving Access to Care @ Nicklaus Children's Pediatric Specialists ... Email: mattfield616@gmail.com #opennetwork #layoffs #jobsearching.
# Laura Viksnins, MSN, CPNP-PC - Pediatric Nurse ...
# https://www.linkedin.com/in/laura-viksnins-msn-cpnp-pc-1129a5136?trk=public_profile_browsemap
# North Florida Pediatrics - NFPVanderbilt University School of Nursing ... Pediatric Primary Care Nurse Practitioner. lviksnins@gmail.com ...
# Adelene Soto - Advanced Practice Registered Nurse
# https://www.linkedin.com/in/adelene-soto-a49a4355
# PEDIATRIC EPILEPSY AND NEUROLOGY SPECIALISTSUniversity of Florida ... Patient Safety | Organizational Development Contact Adelene via asotodnp@gmail.com ...
# Lori Dart Hearne - Certified Pediatric Nurse Practitioner
# https://www.linkedin.com/in/lori-darthearne
# Marijuana Doctors - Medical Marijuana - Florida Legal Use of ...
# https://compassionclinicflorida.com/
# As a MMJ doctor, he is knowledgeable in Florida medical marijuana regulations and qualified to evaluate individuals for the ... drbobgoethe@gmail.com.
# 𝟓𝟎 𝐇𝐎𝐒𝐏𝐈𝐓𝐀𝐋𝐒 𝐈𝐌𝐆'𝐬 𝐂𝐀𝐍 𝐆𝐄𝐓 𝐀 𝐑𝐎𝐓𝐀𝐓𝐈𝐎𝐍 𝐈𝐍 ...
# https://www.doctorsebas.com/post/3cf89da0
# 21-May-2020 —
# EHSP Day: My Earth = My Health
# https://www.spelman.edu/academics/majors-and-programs/environmental-and-health-sciences/calendar/2021/04/21/default-calendar/ehsp-day?vgo_ee=LRRV6glqIfcVPcYsJBrMHi%2FZD%2BmsUFpJrc5fHf6IoVE%3D
# 21-Apr-2021 —
# Lost on the Frontline
# https://khn.org/news/lost-on-the-frontline-health-care-worker-death-toll-covid19-coronavirus/
# Place of Work: Hsu & Loy Medical Group in Margate, Florida Date of Death: March 24, 2020 ... Michelle Andrews: andrews.khn@gmail.com, @mandrews110.
# Physicians
# https://centralfloridamedicalsociety.com/physicians/
# CentralFloridaMedicalSociety@gmail.com · Facebook · Instagram · Facebook · Instagram ... Abraham Woods III – MD · Urology · Jacqueline Hamilton – MD.
# Holistic Pediatrics and Family Health Through Osteopathic ...
# https://www.holisticpediatrics.com/
# 206-714-3118. mindofone@gmail.com ... Holistic Pediatrics and Family Health through Osteopathic Manipulation. As a Neurologist I have found Osteopathic ...
# Chapters & Groups - Indiana University Alumni Association
# https://alumni.iu.edu/chapters-groups/index.html
# 125 results —
# Our Team
# https://emscimprovement.center/about/team/
# Kate Remick, MD Co-Director Charles Macias MD, MPH Co-Director Marc Auerbach, MD, ... Marc Auerbach, MD, MSCi ... ReneTeeler@gmail.com More Information.
# How Much Do Pediatric Nurses Make In The USA?
# https://www.shiftmed.com/blog/how-much-do-pediatric-nurses-make/
# 04-Jul-2022 —
# Editorial Board
# https://www.neonatologytoday.net/board.php
# lomalindapublishingcompany@gmail.com ... Willa Drummond, MD, MS, Professor of Pediatrics, University of Florida College of Medicine.
# Physician–patient racial concordance and disparities in ...
# https://www.pnas.org/doi/10.1073/pnas.1913405117
# by BN Greenwood · 2020 · Cited by 356 —
# Pediatric Physical Therapy in Portsmouth
# https://lighthousept.com/portsmouth-pediatric-physical-therapy/
# 1 Cate Street Portsmouth NH (603) 431-0277 | 60 Pointe Place Suite 1 Dover NH (603) 740-1300 lighthousept@gmail.com · Lighthouse Physical Therapy.
# Pediatric fibrocartilaginous embolism inducing paralysis ...
# https://europepmc.org/article/med/31659479
# by R Ahluwalia · 2019 —
# Hava Ladinsky, MD | Pediatrics, Allergy & Immunology Doctor
# https://premierallergist.com/md/hava-ladinsky-md/
# Hava Ladinsky. kmattikalli@gmail.com2021-10-18T23:56:16-04:00 ... Fellowship: Allergy and Immunology at University of South Florida, Tampa ...
# sam_resume.pdf - Sumanta Bhattacharyya 1-980-319-2883
# https://www.coursehero.com/file/105931867/sam-resumepdf/
# Utpal Diwan: udiwan@gmail.com. ~Subhash Avasare (Civil 71, H8). CONDOLENCE MESSAGES from OTHER BATCHMATES. We lost our live-wire friend Kedar Diwan.
# Pediatric cancer: Mom asks for painted rocks for son's grave
# https://www.today.com/parents/pediatric-cancer-mom-asks-painted-rocks-son-s-grave-t163726
# 02-Oct-2019 —
# Chapters & Groups: Alumni Relations
# https://alumni.iupui.edu/chapters-groups/index.html
# 125 results —
# Faculty
# https://www.ubccardio.com/faculty/
# Attended the University of Florida and graduated in 1993 with a degree in Nursing. Read More ... Email:bheilbron@gmail.com. Office:350-1144 Burrard St., ...
# NEXT | Children's National Hospital Foundation
# https://childrensnational.org/giving/get-involved-new/join-us/next
# We fuel pediatric discoveries and innovative programs and support world-class care. ... passionate about advancing pediatric health. ... B.Hayes@gmail.com ...
# Social media
# https://en.wikipedia.org/wiki/Social_media
# ... WeChat, Instagram, QZone, Weibo, Twitter, Tumblr, Baidu Tieba, and LinkedIn. ... Google mines data in many ways including using an algorithm in Gmail to ...
# FDA Approves Promising Alzheimer's Treatment
# https://www.fcneurology.net/fda-approves-promising-alzheimers-treatment/
# 07-Jun-2021 —
# Newly Diagnosed | CureDuchenne
# https://cureduchenne.org/newly-diagnosed/
# 15-Apr-2021 —
# Forensic Consultants
# https://www.thename.org/forensic-consultants
# Email: bao3833@gmail.com ... Laura Knight, MD - Board-certified forensic pathologist (AP/CP/FP) ... Medical Licenses in Florida, Michigan, and Ohio
# Five Things We Get Wrong (D'OH) with SEL
# https://www.pacesconnection.com/blog/five-things-we-get-wrong-d-oh-with-sel
# 01-Mar-2021 —
# Podcast - Schimizzi Family Chiropractic
# https://www.schimizziwellnesscenter.com/podcast/
# ... Pediatricians, Medical Freedom with Author Katelyn McCormack 53:18 Raising the Bar in All Areas of Life with Dr ... schimizziwellnesscenter@gmail.com ...
# Current master's degree students
# https://health.ucdavis.edu/nursing/about_us/students/Current_Students/MS_students.html
# Areas of special interest in health care: emergency medicine, pediatrics, surgery, underserved communities. Languages: ... Contact: jljavelet@gmail.com.
# Team Details
# https://diconlab.org/team-details
# Boys Town National Research Hospital. tony.w.wilson@gmail.com · tony.wilson@boystown.org﻿ ... LinkedIn https://www.linkedin.com/in/tony-w-wilson-1bb3038/ ...
# Podcast Archives | CLEAR
# https://clear-institute.org/category/podcast/
# To connect with Kelly, email her at bwellcharlotte@gmail.com. Support the show. Share. Share Episode. Share on Facebook Share on Twitter Share on LinkedIn ...
# Medical Assistance - U.S. Embassy in Uruguay
# https://uy.usembassy.gov/u-s-citizen-services/local-resources-of-u-s-citizens/doctors/
# Florida 830. Ph.: 4222 5353; Policlínica Maldonado ... Maxilofacial.fernandez@gmail.com ... TwitterFacebookYouTubeFlickrInstagramLinkedIn. Footer Disclaimer.
# Financial Assistance
# https://www.hope4atrt.org/financial-assistance
# Runway to Hope (Central Florida). (407) 802-1544. Provides direct assistance to children and families affected by pediatric cancer. ... hope4atrt@gmail.com.
# Current Open Positions (6938)
# https://careers.upmc.com/jobs/search
# no email found
# About | Academy of Rehabilitative Audiology
# https://www.audrehab.org/about
# Check their LinkedIn profile and websites to see which events they've attended ... Bayonetta 3 Chapter 3 A Sinking Feeling Walkthrough · Gmail s New Search ...
# 62 Sex Ed Fails That I Don't Know Whether To Laugh At Or ...
# https://bom7.com/1089103-62-sex-ed-fails-that-i-donampx27t-know-whether-to-laugh-at-or-be-genuinely-concerned-for
# 15 hours ago —
# Max Holloway on what he respects about Alexander ...
# https://sujubu.com/481277-max-holloway-on-what-he-respects-about-alexander-volkanovski
# 22 hours ago —
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8188\1802182532.py in <module>
#       1 for i in range(16):
#       2     data_extraction()
# ----> 3     pagination()
#
# ~\AppData\Local\Temp\ipykernel_8188\1310475000.py in pagination()
#       3
#       4 def pagination():
# ----> 5     next_button = driver.find_element(By.ID,"pnnext")
#       6     next_button.click()
#       7     sleep(3)
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     859             value = '[name="%s"]' % value
#     860
# --> 861         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     862
#     863     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
# --> 444             self.error_handler.check_response(response)
#     445             response["value"] = self._unwrap_value(response.get("value", None))
#     446             return response
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     247                 alert_text = value["alert"].get("text")
#     248             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="pnnext"]"}
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0104ACD3+2075859]
# 	Ordinal0 [0x00FDEE61+1633889]
# 	Ordinal0 [0x00EDB7BD+571325]
# 	Ordinal0 [0x00F0AC2F+764975]
# 	Ordinal0 [0x00F0AE1B+765467]
# 	Ordinal0 [0x00F3D0F2+970994]
# 	Ordinal0 [0x00F27364+881508]
# 	Ordinal0 [0x00F3B56A+963946]
# 	Ordinal0 [0x00F27136+880950]
# 	Ordinal0 [0x00EFFEFD+720637]
# 	Ordinal0 [0x00F00F3F+724799]
# 	GetHandleVerifier [0x012FEED2+2769538]
# 	GetHandleVerifier [0x012F0D95+2711877]
# 	GetHandleVerifier [0x010DA03A+521194]
# 	GetHandleVerifier [0x010D8DA0+516432]
# 	Ordinal0 [0x00FE682C+1665068]
# 	Ordinal0 [0x00FEB128+1683752]
# 	Ordinal0 [0x00FEB215+1683989]
# 	Ordinal0 [0x00FF6484+1729668]
# 	BaseThreadInitThunk [0x753F00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307B8E+238]

# %%
# dictionary
google_linkedIn = pd.DataFrame({'title': Title, 'Link':Link, 'Email':Email})
google_linkedIn
# Out:
#                                                  title  \
# 0             Harry Cuevas - MD - Kidsville Pediatrics
# 1    Isabella Clem - Medical Assistant - Milestones...
# 2                        Catherine Limperopoulos' Post
# 3                           Leigh Bouskila, MHA'S Post
# 4    Laura Viksnins, MSN, CPNP-PC - Pediatric Nurse...
# ..                                                 ...
# 151     Holidaycheck business - Helalu.com is for sale
# 152  Garlic Tea Health Benefits and Side Effects - ...
# 153  Free Traffic No Cost Ways to Promote Your Onli...
# 154  62 Sex Ed Fails That I Don't Know Whether To L...
# 155  Max Holloway on what he respects about Alexand...
#
#                                                   Link  \
# 0    https://www.linkedin.com/in/harry-cuevas-44955975
# 1            https://www.linkedin.com/in/isabella-clem
# 2    https://www.linkedin.com/posts/catherine-limpe...
# 3    https://www.linkedin.com/posts/leighbouskila_p...
# 4    https://www.linkedin.com/in/laura-viksnins-msn...
# ..                                                 ...
# 151    https://helalu.com/743296-holidaycheck-business
# 152  https://wpsosyal.com/271913-garlic-tea-health-...
# 153  https://huvzi.com/92514-free-traffic-no-cost-w...
# 154  https://bom7.com/1089103-62-sex-ed-fails-that-...
# 155  https://sujubu.com/481277-max-holloway-on-what...
#
#                                                  Email
# 0    Harry R. Cuevas Bocanegra, M.D. 05/23 Santurce...
# 1    Isabella is adaptable, empathetic, diligent, a...
# 2    Join the Children's National Hospital Prenatal...
# 3    Improving Access to Care @ Nicklaus Children's...
# 4    North Florida Pediatrics - NFPVanderbilt Unive...
# ..                                                 ...
# 151                                       1 day ago —
# 152  ... Naoki Takahashi M D Doctors and Medical St...
# 153  Check their LinkedIn profile and websites to s...
# 154                                    15 hours ago —
# 155                                    22 hours ago —
#
# [156 rows x 3 columns]

# %%
google_linkedIn.to_excel('LinkedIn_General_mails_22_12_2022.xlsx', index=False)

# %% [markdown]
# # Get the links(25)

# %%
from time import sleep

def GetURLOnepage():
    scrolling()
    page_source = BeautifulSoup(driver.page_source)

    time.sleep(3)

    profiles = page_source.find_all('div',class_='artdeco-entity-lockup__title ember-view')
    print(profiles)
    all_profile_url = []
    for profile in profiles:
        URLs = profile.find('a', href =True)
        sales_navigator = (URLs['href'])
        #print(sales_navigator)
        doc_personal_profile = 'https://www.linkedin.com'+ (sales_navigator)
    
        if doc_personal_profile not in all_profile_url:
            all_profile_url.append(doc_personal_profile)
        
        print(all_profile_url)
    return all_profile_url
    length = len(all_profile_url)
    print(length)
#print(GetURL())

# %% [markdown]
# # Multipage URLs

# %%
from time import sleep
#def GetURLsonpages():
input_page = int(input('pages you wanna scrap?'))
    
All_page_data = []

    
    
for page in range(input_page):
    #while True:
    one_page_data  = GetURLOnepage()
    sleep(2)
            
    scrolling()
    sleep(2)
        #Above Scroll Down Till not working according to our requirements
        
        #All_page_data.append(new_page_data)    
            
        #sleep(3)
    next_button = driver.find_element(By.CLASS_NAME,"artdeco-pagination__button--next")
    next_button.click()
    sleep(3)
            
        #new_page_data = GetURLOnepage()
        #sleep(3)
    
    GetURLOnepage()
    scrolling()
    All_page_data = All_page_data + one_page_data 
    sleep(2)
    
    
        #return All_page_data
print(len(All_page_data))
        
#print(GetURLsonpages())
    
    #All_page_data = All_page_data.append(new_page_data)
    #All_page_data = new_page_data + All_page_data
    #sleep(3)
             
    #Getting URLs for all pages
    #URLs_all_page = URLs_all_page + URL_one_page
        
        
    #print(URLs_ALL_PAGE)

    #return All_page_data
    
    
#print(All_page_data)
#print(GetURLsonpages())
# Out:
# pages you wanna scrap?8
# [<div class="artdeco-entity-lockup__title ember-view" id="ember3607">
# <a class="ember-view" data-control-id="cùÌÛUAeF5WcMê" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3608">
# <span data-anonymize="person-name">Lara Matsalla Cavanaugh</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3628">
# <a class="ember-view" data-control-id="
# @*U¶BÑ1ÂUqóK:" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3629">
# <span data-anonymize="person-name">Derrick Owens, MD, IBCLC, FAAP</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3651">
# <a class="ember-view" data-control-id="u++,I èýiF" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3652">
# <span data-anonymize="person-name">Greggy Laroche</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3677">
# <a class="ember-view" data-control-id="!ß­LÍ²,)Øzr" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3678">
# <span data-anonymize="person-name">Daniel Arias Vargas</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3702">
# <a class="ember-view" data-control-id='Äâ¼Ð"C© ¬@£ò' data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3703">
# <span data-anonymize="person-name">Kahlil Shillingford, M.D., P.A.</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3724">
# <a class="ember-view" data-control-id="²|ayß¸G¼Ó%¦¤©" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3725">
# <span data-anonymize="person-name">Paul Kwon</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3748">
# <a class="ember-view" data-control-id="ýDÖLîluéòD" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3749">
# <span data-anonymize="person-name">Christina Morris, MD, FAAP</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3771">
# <a class="ember-view" data-control-id="õED±êñFO°- &gt;" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3772">
# <span data-anonymize="person-name">Yesenia Ramos</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3795">
# <a class="ember-view" data-control-id="âèV»BÛ¨|pCæAË" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3796">
# <span data-anonymize="person-name">Ellen Rodman</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3817">
# <a class="ember-view" data-control-id='§ç©VOä¯"ºítx×' data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3818">
# <span data-anonymize="person-name">Gerardo Rojas</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3840">
# §×^Òï^F" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3841">
# <span data-anonymize="person-name">Barron Johnson</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3862">
# <a class="ember-view" data-control-id="Æ³êYéyK§NÑjÌ" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABfekNABvkF2s47MBd5mdDwDUnLY6kng89k,OUT_OF_NETWORK,h6De?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3863">
# <span data-anonymize="person-name">Barry Lowy</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3885">
# <a class="ember-view" data-control-id="}0°kiKï¢°Lr3" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA8O2BEB0tuYP3__O8zd42lTGuVDMstI520,OUT_OF_NETWORK,YlDf?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3886">
# <span data-anonymize="person-name">Alexis Dietz</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3907">
# <a class="ember-view" data-control-id="\{ìÂJOÏ²Ç¦" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADzFtlQBR4jO_FtlG4Oh1QuavYpqJUonBvI,OUT_OF_NETWORK,tvxv?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3908">
# <span data-anonymize="person-name">Ana Maria Duque Lopez</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3930">
# <a class="ember-view" data-control-id="BÜ¨'B¤¦E  " data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA0s8tgBO4-I9cWNiNdLEjb5aUlAmwzuDOc,OUT_OF_NETWORK,XWt5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3931">
# <span data-anonymize="person-name">Sebastian Tas</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember3953">
# <a class="ember-view" data-control-id="zâDÀ[JCâà*ËÏ&lt;" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAABcQVAB8l6XbobHlVDoLxzSI6sUQf7ot0w,OUT_OF_NETWORK,zD8h?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember3954">
# <span data-anonymize="person-name">Celina Moore, MD, FAAP</span>
# </a>
# </div>]
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABfekNABvkF2s47MBd5mdDwDUnLY6kng89k,OUT_OF_NETWORK,h6De?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABfekNABvkF2s47MBd5mdDwDUnLY6kng89k,OUT_OF_NETWORK,h6De?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA8O2BEB0tuYP3__O8zd42lTGuVDMstI520,OUT_OF_NETWORK,YlDf?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABfekNABvkF2s47MBd5mdDwDUnLY6kng89k,OUT_OF_NETWORK,h6De?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA8O2BEB0tuYP3__O8zd42lTGuVDMstI520,OUT_OF_NETWORK,YlDf?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADzFtlQBR4jO_FtlG4Oh1QuavYpqJUonBvI,OUT_OF_NETWORK,tvxv?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABfekNABvkF2s47MBd5mdDwDUnLY6kng89k,OUT_OF_NETWORK,h6De?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA8O2BEB0tuYP3__O8zd42lTGuVDMstI520,OUT_OF_NETWORK,YlDf?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADzFtlQBR4jO_FtlG4Oh1QuavYpqJUonBvI,OUT_OF_NETWORK,tvxv?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA0s8tgBO4-I9cWNiNdLEjb5aUlAmwzuDOc,OUT_OF_NETWORK,XWt5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABYenG0Bre-kPFonGxmXZbS-mrxCsgaJUY0,NAME_SEARCH,tDo5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAATGKToB-0DW05gL1tGk07wt1EYua3wbCCY,OUT_OF_NETWORK,JSrC?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAApdBs4BQbuVTuEE3ABAte_RHrCbeZPpyf0,OUT_OF_NETWORK,Pazj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACttV3QB67ys58j-M0KMotjPyythzjRgSCk,OUT_OF_NETWORK,tFYY?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAyy2dgB_15PHK610S3oSmmY5meCx0t5aLU,OUT_OF_NETWORK,Bsoa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA9ZCAkB99uQuarjapd4x5plHMI2XTKI6gg,OUT_OF_NETWORK,UJh-?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAB7gEgoBtejAAklTAt0U6ug06ODQHua32pc,OUT_OF_NETWORK,qIDA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKwTcgBIa6BFumI3cAyJIds4Z_z7E7i5pw,OUT_OF_NETWORK,HA5i?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAKZpuoBhOBLgn0Z1x5b1qPOMsF_FvGRB24,OUT_OF_NETWORK,yuNV?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAfhMoQBy2iL0--UXPwL16ABtATWCp7PXME,OUT_OF_NETWORK,ApyL?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAzD64IBFkA-bv1aRupcKlEGEhmMYhzThRQ,OUT_OF_NETWORK,tzzA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABfekNABvkF2s47MBd5mdDwDUnLY6kng89k,OUT_OF_NETWORK,h6De?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA8O2BEB0tuYP3__O8zd42lTGuVDMstI520,OUT_OF_NETWORK,YlDf?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADzFtlQBR4jO_FtlG4Oh1QuavYpqJUonBvI,OUT_OF_NETWORK,tvxv?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA0s8tgBO4-I9cWNiNdLEjb5aUlAmwzuDOc,OUT_OF_NETWORK,XWt5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAABcQVAB8l6XbobHlVDoLxzSI6sUQf7ot0w,OUT_OF_NETWORK,zD8h?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# [<div class="artdeco-entity-lockup__title ember-view" id="ember4097">
# <a class="ember-view" data-control-id="@JFgºò¿Î`~" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4098">
# <span data-anonymize="person-name">Amy A. Lucier</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4120">
# <a class="ember-view" data-control-id="o'X«ÇàHÚk«¯Æ#Æ£" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4121">
# <span data-anonymize="person-name">Karen Baldwin</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4143">
# <a class="ember-view" data-control-id="f5ÜDëç	÷ë$" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4144">
# <span data-anonymize="person-name">Sarah W.</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4165">
# <a class="ember-view" data-control-id="ØÀ¯lCzÂ¨q&amp;\Ò" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADcozzEBDztb0be5sMwGiySzy-O3S_BtZME,NAME_SEARCH,kRuw?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4166">
# <span data-anonymize="person-name">NEERAJ KANCHERLA</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4190">
# <a class="ember-view" data-control-id="ÞYíDM1¦gTWLÅöÖ" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABAIwAsBut-7AbSuS6A7d1f0ne9nZLUDHPQ,OUT_OF_NETWORK,cZ3U?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4191">
# <span data-anonymize="person-name">Karen Kelly</span>
# </a>
# </div>]
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADcozzEBDztb0be5sMwGiySzy-O3S_BtZME,NAME_SEARCH,kRuw?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADcozzEBDztb0be5sMwGiySzy-O3S_BtZME,NAME_SEARCH,kRuw?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABAIwAsBut-7AbSuS6A7d1f0ne9nZLUDHPQ,OUT_OF_NETWORK,cZ3U?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# [<div class="artdeco-entity-lockup__title ember-view" id="ember4097">
# <a class="ember-view" data-control-id="@JFgºò¿Î`~" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4098">
# <span data-anonymize="person-name">Amy A. Lucier</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4120">
# <a class="ember-view" data-control-id="o'X«ÇàHÚk«¯Æ#Æ£" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4121">
# <span data-anonymize="person-name">Karen Baldwin</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4143">
# <a class="ember-view" data-control-id="f5ÜDëç	÷ë$" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4144">
# <span data-anonymize="person-name">Sarah W.</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4165">
# <a class="ember-view" data-control-id="ØÀ¯lCzÂ¨q&amp;\Ò" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADcozzEBDztb0be5sMwGiySzy-O3S_BtZME,NAME_SEARCH,kRuw?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4166">
# <span data-anonymize="person-name">NEERAJ KANCHERLA</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4190">
# <a class="ember-view" data-control-id="ÞYíDM1¦gTWLÅöÖ" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABAIwAsBut-7AbSuS6A7d1f0ne9nZLUDHPQ,OUT_OF_NETWORK,cZ3U?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4191">
# <span data-anonymize="person-name">Karen Kelly</span>
# </a>
# </div>]
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADcozzEBDztb0be5sMwGiySzy-O3S_BtZME,NAME_SEARCH,kRuw?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAAA7l14IBbdOqan0LPi3CvHiGThQ5vGH-iWU,OUT_OF_NETWORK,Uew5?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACIwCHgBr96vB0rhDgSG-JFvlHVhTohuzD8,OUT_OF_NETWORK,Ybxa?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAADetzUBZGQgTN3RtRlpzkHAhdKYKAMAYMs,OUT_OF_NETWORK,goZi?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADcozzEBDztb0be5sMwGiySzy-O3S_BtZME,NAME_SEARCH,kRuw?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABAIwAsBut-7AbSuS6A7d1f0ne9nZLUDHPQ,OUT_OF_NETWORK,cZ3U?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# [<div class="artdeco-entity-lockup__title ember-view" id="ember4241">
# <a class="ember-view" data-control-id="³´PHì¸CBùùDps¶x" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4242">
# <span data-anonymize="person-name">ÍTALO GABRIELE</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4263">
# <a class="ember-view" data-control-id="Ù*ºuCK}¯Ð¤å¤" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4264">
# <span data-anonymize="person-name">Rosa T.</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4285">
# <a class="ember-view" data-control-id="l&gt;Ø	G» ºµ-°»" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4286">
# <span data-anonymize="person-name">Elena Dumalaog</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4313">
# <a class="ember-view" data-control-id="i×FnrMÙ­§  ï&amp;2" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAACdMRzYBUcY_V11QrS9VPie3x90qWjoOGIQ,OUT_OF_NETWORK,6AB8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4314">
# <span data-anonymize="person-name">Sabina Sheikh, MD</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4338">
# <a class="ember-view" data-control-id="Îá¢fD@õì¯&amp;/" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABYP7CwBMKglWkTJ6-Sic-Ya_pe8ufVfaQU,OUT_OF_NETWORK,TP_F?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4339">
# <span data-anonymize="person-name">Danielle Squires</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4360">
# <a class="ember-view" data-control-id="NE)#·kI¯4û¶R" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADaIwqwB-8q9fMvSrA71n2goKCcdzqmiuYI,OUT_OF_NETWORK,jjsj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4361">
# <span data-anonymize="person-name">Beatriz Ortega-Fernandez MD FAAP</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4384">
# <a class="ember-view" data-control-id="ÚpçoÿK ¼YÞòÛ1" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAConIJMBUIq_KtE8aPFF-YaVygycZ6iwEhI,OUT_OF_NETWORK,fCHQ?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4385">
# <span data-anonymize="person-name">Yadira De La Cruz</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4406">
# ¦b" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAuMre8B5tgK377yPhwxvNQBGQFjtucSt_s,OUT_OF_NETWORK,BxyP?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4407">
# <span data-anonymize="person-name">Kaitlin Golembieski</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4429">
# <a class="ember-view" data-control-id="}66UJE	´(	9Ö¸i" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADnXxLYB96u2cF7aDxlH_VEp-o3xwr9WQpU,NAME_SEARCH,o7m7?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4430">
# <span data-anonymize="person-name">Mariana Chacon</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4454">
# <a class="ember-view" data-control-id="­ÜÂ¼±MË`ù" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAcfAqQBSRZ-aFlLM_Syw6AErENOfANlf6c,NAME_SEARCH,1uuZ?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4455">
# <span data-anonymize="person-name">YASLAM BALFAQIH, MD FAAP</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4479">
# <a class="ember-view" data-control-id="s')D6ïE5¦îOºpm" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADDg4a8BQbdxKBrRPh3o0lxBWyKfvGLygWs,OUT_OF_NETWORK,aHtF?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4480">
# <span data-anonymize="person-name">Adam Cutler, MD</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4502">
# <a class="ember-view" data-control-id="=ÛÕtLi2JER^%" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAD7np4UBtK7iRdMifMev3ure9Yvb7BwKPAs,OUT_OF_NETWORK,op3D?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4503">
# <span data-anonymize="person-name">Melissa Zegarra Bustamante</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4525">
# <a class="ember-view" data-control-id="°²ð¡û9Iý©CAêÈï" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAmdG-0B2T3wnHJQf3c7I0H-esdLguUn66U,OUT_OF_NETWORK,YF9I?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4526">
# <span data-anonymize="person-name">Marie Quiñonez MD</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4547">
# <a class="ember-view" data-control-id="³L¹¯ôFsrD" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAl3g6MBVJs7iEASWZv0Ii7oGX4J0m0S_BE,OUT_OF_NETWORK,vWCy?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4548">
# <span data-anonymize="person-name">Jaime Estrada MD FAAP</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4570">
# <a class="ember-view" data-control-id="
# {wC'&gt;`¬ÿ@N" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAACZZBX4B0Ai8BXWTDR-UVAW76vq1ZcYZiaM,OUT_OF_NETWORK,dQMR?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4571">
# <span data-anonymize="person-name">Günce Tolasa Karaman</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4593">
# <a class="ember-view" data-control-id="¶o©£-AâGTms" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADIx-jwBzZO6VPi4ole41HpQQK2jlP_lG4A,OUT_OF_NETWORK,DDhA?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4594">
# <span data-anonymize="person-name">Lorena Frontado Morales</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4616">
# <a class="ember-view" data-control-id='ìb:AÀ³"À6µx+' data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABqzu54BSofU4WAl-qfwET-f1rbCSkQW3Xc,NAME_SEARCH,SkY6?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4617">
# <span data-anonymize="person-name">Kristina (Tina) Hiller, A.S., CPC</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4642">
# <a class="ember-view" data-control-id="9º¹G[¿ûÿÒ!" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABdyuyEBuYojbZtqU-ka7a_4bbVxnSFkQfw,OUT_OF_NETWORK,0PnW?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4643">
# <span data-anonymize="person-name">Dr. Harllow Genovese</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4664">
# <a class="ember-view" data-control-id="Év©BLrk±!2ï" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAHZ9bAB_naAWFhgRoyB_1zQCiP1BvJq9xk,OUT_OF_NETWORK,FXGW?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4665">
# <span data-anonymize="person-name">Ves Dimov, M.D.</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4687">
# <a class="ember-view" data-control-id="®Áu3þGg¡îòYçÔÝ" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAsGA0EBB1jrhFf7MwVxLFaETTFszlhKXGg,OUT_OF_NETWORK,sRzb?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4688">
# <span data-anonymize="person-name">Nicole Gavallas, D.O.</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4709">
# <a class="ember-view" data-control-id="1#;AàýKeªºÊWN^" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAIMK54BsYF1Pmg4xqV7g76LjDJIrvJ0wbo,OUT_OF_NETWORK,TwjI?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4710">
# <span data-anonymize="person-name">Katherine Good</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4732">
# <a class="ember-view" data-control-id="NQÜJ{ÄuÀX" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAABeCqDABKm8-fN7z-HgnvcFchNxcMLTlgmk,OUT_OF_NETWORK,CaBd?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4733">
# <span data-anonymize="person-name">Daniel Kraft</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4754">
# <a class="ember-view" data-control-id="ñ?öC·¥ûvS" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA48rroB1Mh6IxpoZn17lIrlRrTAFGD2DwI,OUT_OF_NETWORK,9Wlt?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4755">
# <span data-anonymize="person-name">Lorraine Ospina- Herrera, MD</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4776">
# <a class="ember-view" data-control-id="-|ÎÐè@o:IÄ&amp;X" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAB_nU-EBlXm0kV_4shR8awFcWiq2VQ98uSU,OUT_OF_NETWORK,Y8PU?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4777">
# <span data-anonymize="person-name">Kelly Koch</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember4799">
# <a class="ember-view" data-control-id="½·ä		àM¤¢5$" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAD6kfaQBt_cl-ZZWL98dr2kpJadk3-QljIw,OUT_OF_NETWORK,2bv8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember4800">
# <span data-anonymize="person-name">Dayna Moore</span>
# </a>
# </div>]
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdMRzYBUcY_V11QrS9VPie3x90qWjoOGIQ,OUT_OF_NETWORK,6AB8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdMRzYBUcY_V11QrS9VPie3x90qWjoOGIQ,OUT_OF_NETWORK,6AB8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABYP7CwBMKglWkTJ6-Sic-Ya_pe8ufVfaQU,OUT_OF_NETWORK,TP_F?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdMRzYBUcY_V11QrS9VPie3x90qWjoOGIQ,OUT_OF_NETWORK,6AB8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABYP7CwBMKglWkTJ6-Sic-Ya_pe8ufVfaQU,OUT_OF_NETWORK,TP_F?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADaIwqwB-8q9fMvSrA71n2goKCcdzqmiuYI,OUT_OF_NETWORK,jjsj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdMRzYBUcY_V11QrS9VPie3x90qWjoOGIQ,OUT_OF_NETWORK,6AB8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABYP7CwBMKglWkTJ6-Sic-Ya_pe8ufVfaQU,OUT_OF_NETWORK,TP_F?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADaIwqwB-8q9fMvSrA71n2goKCcdzqmiuYI,OUT_OF_NETWORK,jjsj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAConIJMBUIq_KtE8aPFF-YaVygycZ6iwEhI,OUT_OF_NETWORK,fCHQ?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABPWaIwBcj-t4zkcuQGmaFauXZYqzBCEufU,OUT_OF_NETWORK,0Quu?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADDMZZ4BUAw7dfhalC6YAeUFT5wlEAjjruw,NAME_SEARCH,RYap?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGdRi4B_JXoz_RxqO-xHvVfz6gI2F1Ypbo,NAME_SEARCH,pHtS?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdMRzYBUcY_V11QrS9VPie3x90qWjoOGIQ,OUT_OF_NETWORK,6AB8?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAABYP7CwBMKglWkTJ6-Sic-Ya_pe8ufVfaQU,OUT_OF_NETWORK,TP_F?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADaIwqwB-8q9fMvSrA71n2goKCcdzqmiuYI,OUT_OF_NETWORK,jjsj?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAConIJMBUIq_KtE8aPFF-YaVygycZ6iwEhI,OUT_OF_NETWORK,fCHQ?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAuMre8B5tgK377yPhwxvNQBGQFjtucSt_s,OUT_OF_NETWORK,BxyP?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwA
_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember7900">
# <span data-anonymize="person-name">Lynn Anne Scheel MD</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember7924">
# <a class="ember-view" data-control-id="Ì}áØG_ÕiË[" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAEp6ZYBIvP0N5c2KqGu47-X2x6dekFa1kM,OUT_OF_NETWORK,hzie?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember7925">
# <span data-anonymize="person-name">Charles Lebowitz, MD, FACP</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember7947">
# <a class="ember-view" data-control-id="À#ÙÖúE§4ô¯8" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAADK6eoMBIiFfcIrA-cPZJuPSRXOePOpSF6A,OUT_OF_NETWORK,tJ-M?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D" id="ember7948">
# <span data-anonymize="person-name">Inelvis del Rio Ramos</span>
# </a>
# </div>]
# ['https://www.linkedin.com/sales/lead/ACwAABQ7ReUBCmEV5ccKi-eWX_PMX0NnM8ae6Mg,NAME_SEARCH,_Hes?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABQ7ReUBCmEV5ccKi-eWX_PMX0NnM8ae6Mg,NAME_SEARCH,_Hes?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdh8d8Buk06b-DYLga7K6Dq5mqBUbPCfpo,OUT_OF_NETWORK,xQKT?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABQ7ReUBCmEV5ccKi-eWX_PMX0NnM8ae6Mg,NAME_SEARCH,_Hes?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdh8d8Buk06b-DYLga7K6Dq5mqBUbPCfpo,OUT_OF_NETWORK,xQKT?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAEo33gB0QBQtwdgu6L7OikJmM0O5dmgh04,OUT_OF_NETWORK,ma3J?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABQ7ReUBCmEV5ccKi-eWX_PMX0NnM8ae6Mg,NAME_SEARCH,_Hes?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdh8d8Buk06b-DYLga7K6Dq5mqBUbPCfpo,OUT_OF_NETWORK,xQKT?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAEo33gB0QBQtwdgu6L7OikJmM0O5dmgh04,OUT_OF_NETWORK,ma3J?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAEp6ZYBIvP0N5c2KqGu47-X2x6dekFa1kM,OUT_OF_NETWORK,hzie?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAABQ7ReUBCmEV5ccKi-eWX_PMX0NnM8ae6Mg,NAME_SEARCH,_Hes?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAACdh8d8Buk06b-DYLga7K6Dq5mqBUbPCfpo,OUT_OF_NETWORK,xQKT?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAEo33gB0QBQtwdgu6L7OikJmM0O5dmgh04,OUT_OF_NETWORK,ma3J?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAEp6ZYBIvP0N5c2KqGu47-X2x6dekFa1kM,OUT_OF_NETWORK,hzie?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAADK6eoMBIiFfcIrA-cPZJuPSRXOePOpSF6A,OUT_OF_NETWORK,tJ-M?_ntb=aGC0YDbTRRyVGbVlfNQXKg%3D%3D']
# 171

# %% [markdown]
# # Data Extraction

# %%
doctor_name = []
job_title = []
doctor_address = []
doctor_mail_web = []
doctors_job_title = []

for linkedIn_url in All_page_data:
    driver.get(linkedIn_url)
    sleep(2)
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    #page_souce = driver.page_source
    page_source = BeautifulSoup(driver.page_source)
    
    
     #Doctor Name
    person_name = page_source.find_all('div',class_='_name-title-container_sqh8tm')
    try:
        name = person_name[0].find('h1').get_text()
        print(name)
        doctor_name.append(name)
        sleep(2)
        
    except:
        no_name = print('Null')
        doctor_name.append(no_name)
    
    person_job = page_source.find_all('div',class_='_lockup-content_p4eb22')
    try:
        job = person_job[1].find('p').get_text()
        print(job)
        job_title.append(job)
        sleep(2)
        
    except:
        no_job = print('Null')
        job_title.append(no_job)
        sleep(2)
     
    person_job_title = page_source.find_all('div', class_='_bodyText_1e5nen _default_1i6ulk')
    try:
        persons_title = person_job_title[0].find('span').get_text()
        print(persons_title)
        doctors_job_title.append(persons_title) 
        sleep(1)
    except:
        without_title = print('Null')
        doctors_job_title.append(without_title)
        sleep(1)
        
    
    persons_location = page_source.find('div',class_='_lockup-caption_sqh8tm _bodyText_1e5nen _default_1i6ulk _sizeSmall_1e5nen _lowEmphasis_1i6ulk')
    try:
        person_location = persons_location.get_text()
        print(person_location)
        doctor_address.append(person_location)
        sleep(2)
    except:
        general_address = print('United States')
        doctor_address.append(general_address)
        sleep(2)
    
    
   
    """#_contact-info-list_hqxetg
    persons_mail = page_source.find('span', class_='_secondary-link_hqxetg')
    #mail = persons_mail[0]
    print(persons_mail)
    doctor_mail_web.append(persons_mail)
    sleep(2)
    
    
    
    person_mail = page_source.find_all('div',class_='_layout_hqxetg _column_hqxetg _grid_17ha7o _gap-none_17ha7o')
    mail = person_mail[0].find('a', href =True)
    persons_mail = mail[0]
    print(persons_mail)
    sleep(2)
    """
    
    persons_mail = page_source.find('span', class_='_secondary-link_hqxetg')
    #mail = persons_mail[0]
    print(persons_mail)
    doctor_mail_web.append(persons_mail)
    sleep(2)
# Out:
#               Lara Matsalla Cavanaugh
#
#
# Pediatrician at NPCMC
#
# Pediatrician Children’s Medical Center
#
#
#
#
#               Greater Tampa Bay Area
#
# None
#
#             LinkedIn Member
#
# Null
# General Pediatrician at Carithers Pediatrics Group
#
#
#
#
#               Metro Jacksonville
#
# None
#
#             LinkedIn Member
#
# Null
# --
#
#
#
#
#               Ocala, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Medico General y Cirugia Menor at Vida Volunteer
#
# Dr. Daniel Arias (MD IMG)
#
#
#
#
#               Leesburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Bariatric Surgery, Gastric Sleeve Surgeon, Weight Loss Surgery in Florida, USA
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at US Army
#
# Clinical Advisor
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Physician Team Leader for the outpatient telehealth & Pediatrician with Nemours in Orlando, FL.
#
#
#
#
#               Oviedo, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Lakeside Pediatrics
#
#
#
#
#               Lakeland, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatric Emergency Physician at Weatherby Healthcare
#
# Pediatric Emergency Physician at Weatherby Healthcare
#
#
#
#
#               Gulf Breeze, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Internist Physician at Global Health Care for Adults
#
# Occupational medicine at Concentra Urgent Care
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# ER .Pediatrician at Phoenix Physicians,Em care
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatrician
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician and Owner of Coral Ridge Pediatrics
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Médico general en Fundación Clínica Infantil Club Noel
#
#
#
#
#               Pompano Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Physician - General Surgeon
#
#
#
#
#               Pinellas County, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Affiliate Assistant Professor of Pediatrics at Florida Atlantic University Charles E Schmidt College of Medicine
#
# Pediatrician / Humanitarian
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# General Pediatrician at GROWING TOGETHER PEDIATRICS, LLC
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatrics Associates, P.A.
#
#
#
#
#               Pensacola, Florida, United States
#
# None
#
#               NEERAJ KANCHERLA
#
#
# General Physician at Lybrate
#
#
# Physician
#
#
#
#
#               Newark, Delaware, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Myrtle Avenue Pediatrics
#
#
#
#
#               Dunedin, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# INSTITUTE FOR INTEGRATIVE NUTRITION CERTIFIED HEALTH COACH / PEDIATRICS  & PEDIATRIC CRITICAL CARE  IN HOSPITAL DE CLÍNICAS CARACAS
#
#
#
#
#               Pompano Beach, Florida, United States
#
# None
#
#               Rosa T.
#
#
#                         AdventHealth West Florida
#
# Pediatrician at AdventHealth West Florida Division
#
#
#
#
#               Wesley Chapel, Florida, United States
#
# None
#
#               Elena Dumalaog
#
#
# Primary Care Pediatrician at ORLANDO MEDICAL HEALTH CARE
#
#
# Pediatrician
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Kings Bay Pediatrics
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatric Hospitalist at Brandon Regional Hospital
#
# Pediatric Hospitalist
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Medical Doctor at corporacion municipal vina del mar para el desarrollo social
#
# Physician
#
#
#
#
#               Opa-Locka, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatric Associates, South Florida
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#               Mariana Chacon
#
#
#                         NATIONAL PEDIATRIC CENTER
#
# Medical Doctor at NATIONAL PEDIATRIC CENTER
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#               YASLAM BALFAQIH, MD FAAP
#
#
# Pediatric Hospitalist at Gulf Coast Regional Medical Center - Panama City, FL
#
#
# General Pediatrician & Pediatric Hospitalist
#
#
#
#
#               Panama City, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Pediatric Associates, South Florida
#
# Experienced Board Certified Pediatrician
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatric Associates
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Owner @ Dr Q Pediatrics
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Broward Health
#
# Pediatrician
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Community Health Centers, Inc.
#
#
#
#
#               Winter Park, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
#  Board certified pediatrician
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#               Kristina (Tina) Hiller, A.S., CPC
#
#
#                         North Florida Surgeons
#
# CPC
#
#
#
#
#               Saint Johns, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Primary Care Clinic
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Allergist/Immunologist at Cleveland Clinic, Clinical Associate Professor, FAU Charles E. Schmidt College of Medicine
#
#
#
#
#               Miami Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Hospitalist at MEDNAX, Health Solutions Partner
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
# Null
# General Pediatrician at Pediatric Associates
#
#
#
#
#               Greater Orlando
#
# None
#
#             LinkedIn Member
#
# Null
# Retired pediatrician at Palm Beach Pediatrics
#
#
#
#
#               Lake Worth, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Physician at South Florida Pediatric Partners
#
# Medical Doctor at Roads Pediatrics
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
# Null
# Physician, Surgical Oncology Fellow at University of Miami/Jackson Memorial Hospital
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatric Associates
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# General Surgery Physician Practice Manager Baptist Health South Florida
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Beaches Family Health Center
#
# Telemedicine - Nemours Children's Clinic
#
#
#
#
#               Metro Jacksonville
#
# None
#
#               Sandra Al Tamimi MD
#
#
#                         Johns Hopkins All Children's Hospital
#
# Pediatric Resident Physician at Johns Hopkins All Children's Hospital
#
#
#
#
#               St Petersburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Miami Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# pediatrician at Lori McAuliffe MD, PA
#
# pediatrician at Lori McAuliffe MD, PA
#
#
#
#
#               St Petersburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Medical Demonstrator, Internal Medicine Department at University of Hail
#
# Medical Demonstrator, Internal Medicine Dept. College of Medicine, University of Hail
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician, Joe DiMaggio Children's Hospital
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Lakeland Regional Health
#
#
#
#
#               Lakeland, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Tallahassee, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at APC Pediatrics
#
#
#
#
#               Bradenton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Hospitalist for Reid Health
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
# Null
# South Florida Concierge Pediatrician
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatric Associates, Inc.
#
#
#
#
#               Hollywood, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# General Internist at Optum
#
# Physician
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatric Hospitalist at St Joseph’s Women’s Hospital at ST JOSEPH'S WOMEN'S HOSPITAL
#
# Medical Director Newborn Nursery at St Joseph’s Women ‘s Hospital
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Hospitalist & US Army Medical Service Corp. Officer
#
#
#
#
#               Land O' Lakes, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Physician at Infants and Children, P.A.
#
# Physician Infants and Children, P.A.
#
#
#
#
#               Palm Beach Gardens, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Internist, MD at Gulf Coast Medical Group
#
# Internist, MD at Gulf Coast Medical Group
#
#
#
#
#               Sarasota, Florida, United States
#
# None
#
#               Adam Huillet
#
#
#                         Landstuhl Regional Medical Center
#
# Developmental Pediatrician
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Clinical Trial Investigator at Teradan Clinical Trials
#
# Pediatrician at Corizon Health
#
#
#
#
#               Lakeland, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Resident Physician, USF Morsani- Tampa General Hospital and Johns Hopkins All Children’s Hospital
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Board Certified Pediatrician
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Physician at Community Medical Group
#
# --
#
#
#
#
#               United States
#
# None
#
#             LinkedIn Member
#
# Null
# Bilingual Board Certified Pediatrician
#
#
#
#
#               United States
#
# None
#
#             LinkedIn Member
#
# Null
# at
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Emergency Physician at Broward Health
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatric Hospitalist at Mednax Services, Inc.
#
# Pediatric Hospitalist
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
# Null
# Independent Medical Practice Professional
#
#
#
#
#               Stuart, Florida, United States
#
# None
#
#               John Morrison
#
#
# Pediatric Hospitalist at Johns Hopkins
#
#
# Assistant Professor of Pediatrics at The Johns Hopkins University School of Medicine |
# Academic Pediatric Hospitalist at Johns Hopkins All Children's Hospital
#
#
#
#
#               St Petersburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Hospitalist at Advent Health for Children
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Hospitalist at Pediatric Associates, South Florida
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
#
# Assistant Clinical Professor Medicine & Pediatrics at Jefferson Medical College of Thomas Jefferson University
#
# Internal Medicine & Pediatrics Physician
#
#
#
#
#               Townsend, Delaware, United States
#
# None
#
#             LinkedIn Member
#
#
# expert witness pediatrics at David Weiss MD
#
# Pediatrician
#
#
#
#
#               Jacksonville, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Community Health Center of Connecticut
#
# Pediatrician
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Full-time pediatrician, part-time jazz pianist
#
#
#
#
#               Bonita Springs, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# General Practitioner at Hospital San Juan de Dios, El Carmen de Viboral
#
# Medical Assistant / Home Heath Aide/ Phlebotomy Technician at Cruz Home Care and Educacional Service
#
#
#
#
#               Kissimmee, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Holy Cross Medical Group
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#               Mayank Ohri, MD, MBA
#
#
# Internal Medicine Physician at McLaren Health Care
#
#
# Associate Professor and Academic Hospitalist at Central Michigan University
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Appeals, Pediatrician Case Reviewer at C2C INNOVATIVE SOLUTIONS INC
#
# General Pediatrician
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Hospitalist at Ascension Health
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Chief of Pediatrics at Boca Raton Regional Hospital
#
# Pediatrician at Pediatric Associates, Inc.
#
#
#
#
#               Boca Raton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# General Pediatrician
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Nemours
#
#
#
#
#               Windermere, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric & Adult Urology
#
#
#
#
#               Panama City, Florida, United States
#
# None
#
#               Jamelah Tucker (she/hers)
#
#
# Pediatrician, Pediatric Consultant at JAMELAH D TUCKER MD PA
#
# Pediatrician at JAMELAH D TUCKER MD PA
#
#
#
#
#               Hallandale Beach, Florida, United States
#
# <span class="_secondary-link_hqxetg" data-anonymize="remove">
#                     EasyPeasie.com
#                 </span>
#
#             LinkedIn Member
#
# Null
# Division Chief Academic Pediatrics at Johns Hopkins All Children's Hospital
#
#
#
#
#               St Petersburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at BayCare Health System
#
# Pediatrician and Medical Director of Pediatrics at BayCare Medical Group
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Internist, Hospitalist at Baptist Health South Florida
#
# Internal Medicine Hospitalist at HOMESTEAD HOSPITAL
#
#
#
#
#               Homestead, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Voluntary Assistant Professor of Pediatrics at University of Miami Miller School of Medicine
#
# Bilingual Primary Care Pediatrician with a focus on integrated care
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Board Certified Pediatrician at Night Lite Pediatrics
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatric Hospitalist at Christiana Care Health System
#
# Pediatric Hospitalist at Chrisitiana Care Health Services
#
#
#
#
#               Middletown, Delaware, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Baldwin Pediatrics
#
#
#
#
#               Greater Panama City Area
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Emergency Physician
#
#
#
#
#               Bradenton, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Family HealthCare Network
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Physician, Community Health Systems
#
#
#
#
#               Punta Gorda, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Boynton Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# General Pediatrician
#
#
#
#
#               North Port-Sarasota Area
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# General Practitioner at Doctors' Center Hospital
#
# Primary Care Physician at Clínica Las Mercedes
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Internist at HUSMAN KHAN, M.D., P.A
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# GRADUATE OF COLUMBIA COLLEGE OF MEDICINE AND SURGEON AFFLIATED TO HARLEM MEDICAL CENTER, PEDIATRICS RESIDENCY PROGRAM,
#
#
#
#
#               Palm Harbor, Florida, United States
#
# None
#
#               Dr. Free N. Hess
#
#
# Founder and CEO at PediMom.com
#
# Physician | Child Safety Consultant | Speaker | Founder and CEO of PediMom.com
#
#
#
#
#               Gainesville Metropolitan Area
#
# <span class="_secondary-link_hqxetg" data-anonymize="remove">
#                     PediMom.com
#                 </span>
#
#             LinkedIn Member
#
# Null
# Pediatrician, Blogger, Wife, Mom | Wifey Mommy Doc
#
#
#
#
#               Pompano Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Medical Doctor at Johns Hopkins All Children's Hospital
#
#
#
#
#               St Petersburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Hospitalist Nurse Practitioner
#
#
#
#
#               Greater Orlando
#
# None
#
#             LinkedIn Member
#
# Null
# General Physician
#
#
#
#
#               Boynton Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Angel Kids Pediatrics
#
#
#
#
#               Neptune Beach, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# General Medicine Practioner at US Army
#
# MMJ Physician at Medical Marijuana Treatment Clinics of Florida
#
#
#
#
#               Panama City, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Orlando Health Physician Associates
#
#
#
#
#               Greater Orlando
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Children's Medical Center
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
# Null
# Null
# Null
# United States
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Dr. McElroy's Pediatrics
#
#
#
#
#               Tampa, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# --
#
#
#
#
#               United States
#
# None
#
#             LinkedIn Member
#
# Null
# allergist
#
#
#
#
#               Naples, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Choreographer/ director at Self
#
# Physician-Pediatrician.  President &Owner of Sunshine Pediatrics of Lutz/Creator of BOLLYSOULFIT
#
#
#
#
#               Lutz, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# General Practitioner at Portmore Medical Services
#
# General Practitioner at DeCarteret Medical Centre
#
#
#
#
#               Land O' Lakes, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Internal Medicine Physician, Co-Founder of Miami Comprehensive Medicine Group
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#               Judith Leal
#
#
# Medico Pediatra at Autónomo
#
# Pediatrician. Registered Medical Assistant.
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Orlando Health
#
#
#
#
#               Orlando, Florida, United States
#
# None
# Null
# Null
# Null
# United States
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Physician Advisor at SUMMUS
#
# Pediatrician
#
#
#
#
#               Greater Tampa Bay Area
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Pediatric Associates, South Florida
#
#
#
#
#               Hialeah, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Physician and General Surgeon at Fishermen's Hospital, Inc.
#
#
#
#
#               Marathon, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Clinical Assistant Professor at Florida International University
#
# Attending Physician, Pediatric Rheumatology
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at PREMIER PEDIATRICS LLC
#
# Pediatrician
#
#
#
#
#               Ocala, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Pediatrics in Brevard
#
# Pediatrician at Pediatrics in Brevard
#
#
#
#
#               Melbourne, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Physicians Primary Care Ft. Myers, Fl
#
#
#
#
#               Fort Myers, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician
#
#
#
#
#               Port Charlotte, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Shari Geismar DO
#
#
#
#
#               Greater Orlando
#
# None
#
#             LinkedIn Member
#
# Null
# Internist
#
#
#
#
#               Altamonte Springs, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# MD, FAAP at Pediatric Associates, South Florida
#
# Pediatrician at Mount Sinai Medical Center Miami Beach
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatric Hospitalist at University of South Florida
#
# General Pediatrician
#
#
#
#
#               St Petersburg, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Physician at Asthma & Allergy Associates of Florida
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#               Haniet Cordovi
#
#
#                         Sanitas Medical Center
#
# General Practitioner at Sanitas Palmetto Hialeah
#
#
#
#
#               Hialeah, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Clinical Preceptor at Larkin Community Hospital
#
# Medical Director of Pediatrics at Miami Beach Community Health Center
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Chiropractic Internist at Frontier Spine and Health Care
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Ascension
#
# --
#
#
#
#
#               Atlantic Beach, Florida, United States
#
# None
#
#               Dr. Damacio Pagan
#
#
# HOSPITAL GENERAL CASTANER at EMERGENCY ROOM HOSPITAL
#
# Medical Director at ORLANDO FAMILY MEDICAL INC
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Resident Physician at Nemours Children's Hospital
#
#
#
#
#               United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Hospital
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Primary Care Pediatrician
#
#
#
#
#               Boynton Beach, Florida, United States
#
# None
#
#               Jolie Szocki
#
#
#                         Watson Clinic LLP
#
# Pediatrician
#
#
#
#
#               Lakeland, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# GENERAL PEDIATRICIAN
#
#
#
#
#               Lutz, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Resident at HUEH
#
# Worked at Foyer Saint Camille Hospital
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Broward Health
#
# Pediatrician Broward Community and Family Health Centers Inc.
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# --
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
# Null
# Internist/cardiologist at Eisman & Eisman, MD PA
#
#
#
#
#               Miami-Fort Lauderdale Area
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Pediatric Associates, South Florida
#
# Urgent Care Physician - Miami Children's Health System
#
#
#
#
#               Miami, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatric Resident UFJAX
#
#
#
#
#               Tallahassee, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# at
#
#
#
#
#               Greater Orlando
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at Rainbow Pediatrics Panama City
#
#
#
#
#               United States
#
# None
#
#             LinkedIn Member
#
#
# Realtor Associate at ColdwellBanker
#
# Pediatrician at Cano health
#
#
#
#
#               Fort Lauderdale, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# Resident Physician at Arnold Palmer Hospital for Children
#
# General Pediatrician at Pediatrics in Brevard
#
#
#
#
#               Rockledge, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Internist at Bond Clinic, PA
#
#
#
#
#               Winter Haven, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Physician/ internist at Barnabas Health
#
#
#
#
#               Fleming Island, Florida, United States
#
# None
#
#             LinkedIn Member
#
#
# General Physician at   Medical Center
#
# General Physician
#
#
#
#
#               Jacksonville, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# --
#
#
#
#
#               United States
#
# None
#
#               joselyn Arcelin, M.D., MBA
#
#
#                         Conviva Care Centers
#
# Physician
#
#
#
#
#               Metro Jacksonville
#
# None
#
#             LinkedIn Member
#
#
# Pediatrician at Nemours
#
# Associate Program Director at Nemours duPont Hospital for Children
#
#
#
#
#               Wilmington, Delaware, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Pediatrician at PHCA
#
#
#
#
#               Greater Tampa Bay Area
#
# None
#
#             LinkedIn Member
#
# Null
# Hospital & Health Care Professional
#
#
#
#
#               Orlando, Florida, United States
#
# None
#
#             LinkedIn Member
#
# Null
# Medical Practice Professional
#
#
#
#
#               Jacksonville, Florida, United States
#
# None

# %% [markdown]
# # Creating Dictionary for data (Pandas dataframe)

# %%
# dictionary

urgentcare_docs_florida = pd.DataFrame({'Name': doctor_name, 'Company':job_title, 'Title':doctors_job_title, 'Address':doctor_address, 'Email_Web':doctor_mail_web})
urgentcare_docs_florida
# Out:
#                                                   Name  \
# 0    \n              Lara Matsalla Cavanaugh\n
# 1              \n            LinkedIn Member\n
# 2              \n            LinkedIn Member\n
# 3              \n            LinkedIn Member\n
# 4              \n            LinkedIn Member\n
# ..                                                 ...
# 166  \n              joselyn Arcelin, M.D., MBA\n  ...
# 167            \n            LinkedIn Member\n
# 168            \n            LinkedIn Member\n
# 169            \n            LinkedIn Member\n
# 170            \n            LinkedIn Member\n
#
#                                                Company  \
# 0                            \nPediatrician at NPCMC\n
# 1                                                 None
# 2                                                 None
# 3    \nMedico General y Cirugia Menor at Vida Volun...
# 4                                                 None
# ..                                                 ...
# 166  \n                        Conviva Care Centers...
# 167                        \nPediatrician at Nemours\n
# 168                                               None
# 169                                               None
# 170                                               None
#
#                                                  Title  \
# 0               Pediatrician Children’s Medical Center
# 1    General Pediatrician at Carithers Pediatrics G...
# 2                                                   --
# 3                            Dr. Daniel Arias (MD IMG)
# 4    Bariatric Surgery, Gastric Sleeve Surgeon, Wei...
# ..                                                 ...
# 166                                         Physician
# 167  Associate Program Director at Nemours duPont H...
# 168                               Pediatrician at PHCA
# 169                Hospital & Health Care Professional
# 170                      Medical Practice Professional
#
#                                                Address Email_Web
# 0    \n\n\n\n              Greater Tampa Bay Area\n...      None
# 1    \n\n\n\n              Metro Jacksonville\n    ...      None
# 2    \n\n\n\n              Ocala, Florida, United S...      None
# 3    \n\n\n\n              Leesburg, Florida, Unite...      None
# 4    \n\n\n\n              Boca Raton, Florida, Uni...      None
# ..                                                 ...       ...
# 166  \n\n\n\n              Metro Jacksonville\n    ...      None
# 167  \n\n\n\n              Wilmington, Delaware, Un...      None
# 168  \n\n\n\n              Greater Tampa Bay Area\n...      None
# 169  \n\n\n\n              Orlando, Florida, United...      None
# 170  \n\n\n\n              Jacksonville, Florida, U...      None
#
# [171 rows x 5 columns]

# %% [markdown]
# # Output in Excel

# %%
urgentcare_docs_florida.to_excel('urgentcare_docs_florida_2.xlsx', index=False)

# %%
from time import sleep

# Getting the Current URL
first_page = driver.get(first_page_url) 

sleep(1)
##############
# get request
response_1 = requests.get(first_page_url)
print(response_1)
sleep(1)
#Status Code,  Getting the Access from desire Website
response_1.status_code

sleep(1)
# soup object lxml
soup_page_1 = BeautifulSoup(response.content, 'html.parser')
#soup = BeautifulSoup(response.content, 'lxml')
soup_page_1
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Sales Navigator</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <style>
#       /* stylelint-disable */
#       .initial-load-animation {
#         padding-top: 96px;
#         width: 200px;
#         margin: 0 auto;
#         transform: scale(1);
#         transition: transform .5s ease;
#       }
#       .salesnav-image {
#         background-image: url('https://static.licdn.com/aero-v1/sc/h/v4ody32j7r2zqlkj9lxg96x3');
#         height: 55px;
#         width: 55px;
#         margin: 0 auto;
#         margin-bottom: 32px;
#         transform: translate(0, 0);
#         opacity: 1;
#         transition: all .5s ease-out;
#       }
#       .loading-bar {
#         width: 130px;
#         height: 2px;
#         margin: 0 auto;
#         border-radius: 2px;
#         background-color: #CFCFCF;
#         position: relative;
#         overflow: hidden;
#         z-index: 1;
#         transform: rotateY(0);
#         transition: transform .3s ease-in;
#       }
#       .blue-bar {
#         height: 100%;
#         width: 68px;
#         position: absolute;
#         transform: translate(-34px, 0);
#         background-color: #0073B1;
#         border-radius: 2px;
#         animation: initial-loading 1.5s infinite ease;
#       }
#       @keyframes initial-loading {
#         0% {
#           transform: translate(-34px, 0);
#         }
#         50% {
#           transform: translate(96px, 0);
#         }
#         100% {
#           transform: translate(-34px, 0);
#         }
#       }
#       .boot-complete .initial-loading-state,
#       .hide-loading.initial-loading-state {
#         display: none;
#       }
#       /* stylelint-enable */
#     </style>
# <meta content="%7B%22alternativeId%22%3A%22originalId%22%2C%22modulePrefix%22%3A%22lighthouse-web%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22environment%22%3A%22production%22%2C%22rootURL%22%3A%22%2F%22%2C%22locationType%22%3A%22auto-hash-params%22%2C%22historySupportMiddleware%22%3Atrue%2C%22autoHashConfig%22%3A%7B%22maxQueryParamBytes%22%3A4096%7D%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22EXTEND_PROTOTYPES%22%3A%7B%22Date%22%3Afalse%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Afalse%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%2C%22plugins%22%3A%7B%7D%7D%2C%22eyeglass%22%3A%7B%22cssDir%22%3A%22assets%22%2C%22relativeAssets%22%3Afalse%7D%2C%22changeTracker%22%3A%7B%22auto%22%3Afalse%2C%22trackHasMany%22%3Afalse%7D%2C%22tracking%22%3A%7B%22appId%22%3A%22com.linkedin.sales2.d_web%22%2C%22topicPrefix%22%3A%22%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22desktop%22%7D%2C%22comScore%22%3A%7B%22enabled%22%3Afalse%7D%2C%22validation%22%3A%7B%22throwOnError%22%3Afalse%7D%7D%2C%22lix%22%3A%7B%22lixKeys%22%3A%5B%22lss.hue-infra-migration%22%2C%22lss.hue-infra-theme%22%2C%22lss.hue-infra-page-all-routes%22%2C%22lss-industry-v2-FE%22%2C%22lss-sso-idp%22%2C%22lss.search.last_viewed_column%22%2C%22lss-search.occupation-filter%22%2C%22lss.persona.enable-api.member%22%2C%22lss.relationship-explorer.member%22%2C%22enterprise.multiadmin.lss.accountcenter.debranding%22%2C%22lss-desktop-internal-feedback%22%2C%22lss.saving_lists_alerts.manual_list_autosave%22%2C%22lss.saving_lists_alerts.add_to_list_cta%22%2C%22lss-alert-tab-to-pill%22%2C%22lss.profile.useNewRecommendationsApi%22%2C%22lss.ssi.allow-guest-users%22%2C%22lss_custom_list.list_entity_edit_modal%22%2C%22lss.pages.lead-page.skills%22%2C%22lss-search-account-search-account-list-filter-member%22%2C%22lss.save-cta.redesign%22%2C
...
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static.licdn.com/aero-v1/sc/h/dd8hozh02x0gv5e4tfxttjppy" name="i18nIntlPolyfillUrl"/>
# <meta content="pk" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;48b50ab9-5323-4683-ac9d-87f697ecc1fa" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(lighthouse-web,lighthouse-web)", "version": "1.0.3124", "trackingId": [16, 1, 64, 56, -116, 25, 75, -33, -90, 126, -106, 4, 103, -59, 38, -113]}' name="applicationInstance"/>
# <meta content="30dbefa0-d23f-4c7b-a55c-14827713b299" name="clientPageInstanceId"/>
# <meta content="lighthouse-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.0.3124" name="serviceVersion"/>
# <meta content="AAXwV07oZoLEbEE8u37yRA==" name="treeID"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lixV3Mode":false,"lix":{"lss.pages.save-cta.encourage-saves":{"trackingInfo":null,"testKey":"lss.pages.save-cta.encourage-saves","treatment":"control","primaryEvaluationUrn":null},"lss.pages.lead-page.skills":{"trackingInfo":null,"testKey":"lss.pages.lead-page.skills","treatment":"control","primaryEvaluationUrn":null},"lss-alert-tab-to-pill":{"trackingInfo":null,"testKey":"lss-alert-tab-to-pill","treatment":"enabled","primaryEvaluationUrn":null},"lss.growth.onboarding.contextual-tooltips-v2-all-tiers":{"trackingInfo":null,"testKey":"lss.growth.onboarding.contextual-tooltips-v2-all-tiers","treatment":"enabled","primaryEvaluationUrn":null},"lss.buyer-interest.dashboard.product-category-interest":{"trackingInfo":null,"testKey":"lss.buyer-interest.dashboard.product-category-interest","treatment":"control","primaryEvaluationUrn":null},"lss.pages.save-cta.consistent-experience":{"trackingInfo":null,"testKey":"lss.pages.save-cta.consistent-experience","treatment":"control","primaryEvaluationUrn":null},"lss.profile.useNewRecommendationsApi":{"trackingInfo":null,"testKey":"lss.profile.useNewRecommendationsApi","treatment":"control","primaryEvaluationUrn":null},"lss-lead-page-latest-touch-point":{"trackingInfo":null,"testKey":"lss-lead-page-latest-touch-point","treatment":"enabled","primaryEvaluationUrn":null},"lss.buyer-interest.activities.filters":{"trackingInfo":null,"testKey":"lss.buyer-interest.activities.filters","treatment":"enabled","primaryEvaluationUrn":null},"lss.search.keywords-to-filters.member":{"trackingInfo":null,"testKey":"lss.search.keywords-to-filters.member","treatment":"control","primaryEvaluationUrn":null},"lss.relationship-explorer.member":{"trackingInfo":null,"testKey":"lss.relationship-explorer.member","treatment":"control","primaryEvaluationUrn":null},"lss.search.sub-nav-consistency":{"trackingInfo":null,"testKey":"lss.search.sub-nav-consistency","treatment":"control","primaryEvaluationUrn":null},"lss.ssi.allow-guest-users":{"trackingInfo":null,"testKey":"lss.ssi.allow-guest-users","treatment":"enabled","primaryEvaluationUrn":null},"lss.growth.retry-onboarding":{"trackingInfo":null,"testKey":"lss.growth.retry-onboarding","treatment":"control","primaryEvaluationUrn":null},"lss-search.account-lti-headcount":{"trackingInfo":null,"testKey":"lss-search.account-lti-headcount","treatment":"enabled","primaryEvaluationUrn":null},"lss.hue-infra-migration":{"trackingInfo":null,"testKey":"lss.hue-infra-migration","treatment":"control","primaryEvaluationUrn":null},"lss-desktop-internal-feedback":{"trackingInfo":null,"testKey":"lss-desktop-internal-feedback","treatment":"control","primaryEvaluationUrn":null},"lss.notifications.buyer-activities-aggregation":{"trackingInfo":null,"testKey":"lss.notifications.buyer-activities-aggregation","treatment":"control","primaryEvaluationUrn":null},"lss.pages.circle-of-influence":{"trackingInfo":null,"testKey":"lss.pages.circle-of-influence","treatment":"control","primaryEvaluationUrn":null},"lss.growth.reduced-onboarding-flow":{"trackingInfo":null,"testKey":"lss.growth.reduced-onboarding-flow","treatment":"control","primaryEvaluationUrn":null},"lss.search.saved-label-on-entity-lockup":{"trackingInfo":null,"testKey":"lss.search.saved-label-on-entity-lockup","treatment":"control","primaryEvaluationUrn":null},"lss.pages.new-lead-page.relationship-empty-states-layout":{"trackingInfo":null,"testKey":"lss.pages.new-lead-page.relationship-empty-states-layout","treatment":"enabled","primaryEvaluationUrn":null},"lss.saving_lists_alerts.add_to_list_cta":{"trackingInfo":null,"testKey":"lss.saving_lists_alerts.add_to_list_cta","treatment":"control","primaryEvaluationUrn":null},"lss-search.occupation-filter":{"trackingInfo":null,"testKey":"lss-search.occupation-filter","treatment":"control","primaryEvaluationUrn":null},"lss-industry-v2-FE":{"trackingInfo":null,"testKey":"lss-industry-v2-FE","treatment":"enabled","primaryEvaluationUrn":null},"lss-pages-plt-improvement":{"trackingInfo" ...
# <meta content="true" name="isBrowserSupported"/>
# <meta content="true" name="isGuest"/>
# <meta data-mode="VANILLA" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="true" name="isQueryTunnelRequestSupported">
# <link href="https://static.licdn.com/aero-v1/sc/h/f5hkqprfr6biroduqe7rq9cz4" rel="stylesheet"/>
# <link href="https://static.licdn.com/aero-v1/sc/h/3wqy8dcap3gz18m5geze7ptas" rel="stylesheet"/>
# <meta content="https://static.licdn.com/aero-v1/sc/h/4upgxfhayj4r4ly3uoyyw46cp" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# </meta></head>
# <body>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <div id="hue-web-menu-outlet"></div>
# <div id="hue-web-modal-outlet"></div>
# <div id="hue-web-tooltip-outlet"></div>
# <div id="hue-web-typeahead-outlet"></div>
# <script crossorigin="" data-fastboot-src="assets/polyfill-shared.js" src="https://static.licdn.com/aero-v1/sc/h/1yylczmz7x5dapxgx5r0jeujt"></script>
# <script crossorigin="" data-fastboot-src="assets/polyfill-legacy.js" nomodule="" src="https://static.licdn.com/aero-v1/sc/h/66viir3qw9l3vz1ln34nhfwfh"></script>
# <script crossorigin="" data-fastboot-src="assets/polyfill-evergreen.js" src="https://static.licdn.com/aero-v1/sc/h/a8q6glm6zvu7gvt3mhab9x3zv"></script>
# <div class="initial-loading-state">
# <div class="initial-load-animation">
# <div class="salesnav-image"></div>
# <div class="loading-bar">
# <div class="blue-bar"></div>
# </div>
# </div>
# </div>
# <script crossorigin="" data-fastboot-src="assets/vendor.js" src="https://static.licdn.com/aero-v1/sc/h/c50stgqt3n40de7jykwm63wbp"></script>
# <script crossorigin="" data-fastboot-src="/assets/chunk.107.f0e416ed67b3dbb4b794.js" src="https://static.licdn.com/aero-v1/sc/h/2cd6qxgv7e7mcm1g1ya4ty91x"></script>
# <script crossorigin="" data-fastboot-src="/assets/chunk.143.8026422395e0a2e2a099.js" src="https://static.licdn.com/aero-v1/sc/h/5a5hckgbbk3dswv2ku3x3y65z"></script>
# <script crossorigin="" data-fastboot-src="assets/i18n/support_en_US.js" src="https://static.licdn.com/aero-v1/sc/h/48mupi73v9sl5aem88vozeikm"></script>
# <script crossorigin="" data-fastboot-src="assets/lighthouse-web.js" src="https://static.licdn.com/aero-v1/sc/h/qlt3k8w456rmi99idnbxii1q"></script>
# <div id="artdeco-modal-outlet"></div>
# <!--%SSR_BODY*[]%-->
# <div id="ember-panel-outlet"></div>
# </body></html>

# %%
"""

#URLs_all_page = []
input_page = int(input('pages you wanna scrap?'))

#def GetURLsonpages():
URLs_all_page = []
    
    
    
for page in range(input_page):
    URL_one_page = all_profile_url
    #URL_one_page = GetURLOnepage()
    sleep(5)
    scrolling()
    #Above Scroll Down Till not working according to our requirements
    
    
    #artdeco-pagination__button
    #artdeco-pagination__button--next
    sleep(5)
    next_button = driver.find_element(By.CLASS_NAME, "artdeco-pagination__button--next")
    next_button.click()
        
    #Getting URLs for all pages
    URLs_all_page = URLs_all_page + URL_one_page
    sleep(5)
    
    
    #print(URLs_ALL_PAGE)
print(len(URLs_all_page))
    #return URLs_all_page
    
    
print(URLs_all_page)
#print(GetURLsonpages())


"""
# Out:
# '\n\n#URLs_all_page = []\ninput_page = int(input(\'pages you wanna scrap?\'))\n\n#def GetURLsonpages():\nURLs_all_page = []\n    \n    \n    \nfor page in range(input_page):\n    URL_one_page = all_profile_url\n    #URL_one_page = GetURLOnepage()\n    sleep(5)\n    scrolling()\n    #Above Scroll Down Till not working according to our requirements\n    \n    \n    #artdeco-pagination__button\n    #artdeco-pagination__button--next\n    sleep(5)\n    next_button = driver.find_element(By.CLASS_NAME, "artdeco-pagination__button--next")\n    next_button.click()\n        \n    #Getting URLs for all pages\n    URLs_all_page = URLs_all_page + URL_one_page\n    sleep(5)\n    \n    \n    #print(URLs_ALL_PAGE)\nprint(len(URLs_all_page))\n    #return URLs_all_page\n    \n    \nprint(URLs_all_page)\n#print(GetURLsonpages())\n\n\n'

# %% [markdown]
# # Testing for multipage extraction (Own Logic Building [15/12/2022])

# %%
#URLs_all_page = []
#input_page = int(input('pages you wanna scrap?'))
#def GetURLsonpages():

URLs_all_page = []
#for page in range(input_page):
#URL_one_page = all_profile_url
#URL_one_page = GetURLOnepage()
sleep(3)
scrolling()
#Above Scroll Down Till not working according to our requirements
next_button = driver.find_element(By.CLASS_NAME, "artdeco-pagination__button--next")
next_button.click()

# %%
from time import sleep

# Getting the Current URL
second_page_url = driver.current_url 
print(second_page_url)
sleep(1)
##############
# get request
response = requests.get(second_page_url)
sleep(1)
#Status Code,  Getting the Access from desire Website
response.status_code

sleep(1)
# soup object lxml
soup = BeautifulSoup(response.content, 'html.parser')
#soup = BeautifulSoup(response.content, 'lxml')
soup
# Out:
# https://www.linkedin.com/sales/search/people?page=2&query=(recentSearchParam%3A(id%3A2308191012%2CdoLogHistory%3Atrue)%2Cfilters%3AList((type%3ACURRENT_TITLE%2Cvalues%3AList((id%3A3677%2Ctext%3APediatrician%2CselectionType%3AINCLUDED)))%2C(type%3AINDUSTRY%2Cvalues%3AList((id%3A14%2Ctext%3AHospitals%2520and%2520Health%2520Care%2CselectionType%3AINCLUDED)))%2C(type%3AREGION%2Cvalues%3AList((id%3A102095887%2Ctext%3ACalifornia%252C%2520United%2520States%2CselectionType%3AINCLUDED)))))&sessionId=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Sales Navigator</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <style>
#       /* stylelint-disable */
#       .initial-load-animation {
#         padding-top: 96px;
#         width: 200px;
#         margin: 0 auto;
#         transform: scale(1);
#         transition: transform .5s ease;
#       }
#       .salesnav-image {
#         background-image: url('https://static.licdn.com/aero-v1/sc/h/v4ody32j7r2zqlkj9lxg96x3');
#         height: 55px;
#         width: 55px;
#         margin: 0 auto;
#         margin-bottom: 32px;
#         transform: translate(0, 0);
#         opacity: 1;
#         transition: all .5s ease-out;
#       }
#       .loading-bar {
#         width: 130px;
#         height: 2px;
#         margin: 0 auto;
#         border-radius: 2px;
#         background-color: #CFCFCF;
#         position: relative;
#         overflow: hidden;
#         z-index: 1;
#         transform: rotateY(0);
#         transition: transform .3s ease-in;
#       }
#       .blue-bar {
#         height: 100%;
#         width: 68px;
#         position: absolute;
#         transform: translate(-34px, 0);
#         background-color: #0073B1;
#         border-radius: 2px;
#         animation: initial-loading 1.5s infinite ease;
#       }
#       @keyframes initial-loading {
#         0% {
#           transform: translate(-34px, 0);
#         }
#         50% {
#           transform: translate(96px, 0);
#         }
#         100% {
#           transform: translate(-34px, 0);
#         }
#       }
#       .boot-complete .initial-loading-state,
#       .hide-loading.initial-loading-state {
#         display: none;
#       }
#       /* stylelint-enable */
#     </style>
# <meta content="%7B%22alternativeId%22%3A%22originalId%22%2C%22modulePrefix%22%3A%22lighthouse-web%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22environment%22%3A%22production%22%2C%22rootURL%22%3A%22%2F%22%2C%22locationType%22%3A%22auto-hash-params%22%2C%22historySupportMiddleware%22%3Atrue%2C%22autoHashConfig%22%3A%7B%22maxQueryParamBytes%22%3A4096%7D%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22EXTEND_PROTOTYPES%22%3A%7B%22Date%22%3Afalse%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Afalse%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%2C%22plugins%22%3A%7B%7D%7D%2C%22eyeglass%22%3A%7B%22cssDir%22%3A%22assets%22%2C%22relativeAssets%22%3Afalse%7D%2C%22changeTracker%22%3A%7B%22auto%22%3Afalse%2C%22trackHasMany%22%3Afalse%7D%2C%22tracking%22%3A%7B%22appId%22%3A%22com.linkedin.sales2.d_web%22%2C%22topicPrefix%22%3A%22%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22desktop%22%7D%2C%22comScore%22%3A%7B%22enabled%22%3Afalse%7D%2C%22validation%22%3A%7B%22throwOnError%22%3Afalse%7D%7D%2C%22lix%22%3A%7B%22lixKeys%22%3A%5B%22lss.hue-infra-migration%22%2C%22lss.hue-infra-theme%22%2C%22lss.hue-infra-page-all-routes%22%2C%22lss-industry-v2-FE%22%2C%22lss-sso-idp%22%2C%22lss.search.last_viewed_column%22%2C%22lss-search.occupation-filter%22%2C%22lss.persona.enable-api.member%22%2C%22lss.relationship-explorer.member%22%2C%22enterprise.multiadmin.lss.accountcenter.debranding%22%2C%22lss-desktop-internal-feedback%22%2C%22lss.saving_lists_alerts.manual_list_autosave%22%2C%22lss.saving_lists_alerts.add_to_list_cta%22%2C%22lss-alert-tab-to-pill%22%2C%22l
name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(lighthouse-web,lighthouse-web)", "version": "1.0.3032", "trackingId": [-14, 57, 104, -95, -93, -100, 69, 55, -71, 25, -43, -110, -40, -69, -10, 13]}' name="applicationInstance"/>
# <meta content="4a0132ff-0d97-4c82-a8f9-2769861b00f1" name="clientPageInstanceId"/>
# <meta content="lighthouse-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.0.3032" name="serviceVersion"/>
# <meta content="AAXv5BRUEODmydZq9xfUhQ==" name="treeID"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lixV3Mode":false,"lix":{"lss.pages.save-cta.encourage-saves":{"trackingInfo":null,"testKey":"lss.pages.save-cta.encourage-saves","treatment":"control","primaryEvaluationUrn":null},"lss.pages.lead-page.skills":{"trackingInfo":null,"testKey":"lss.pages.lead-page.skills","treatment":"control","primaryEvaluationUrn":null},"lss-alert-tab-to-pill":{"trackingInfo":null,"testKey":"lss-alert-tab-to-pill","treatment":"enabled","primaryEvaluationUrn":null},"lss-remove-sales-preferences":{"trackingInfo":{"urn":"urn:li:guest:8b43fa18-d5ee-4022-84c6-271f776156d1","experimentId":4563256,"segmentIndex":2,"treatmentIndex":1,"trackingUrns":null},"testKey":"lss-remove-sales-preferences","treatment":"enabled","primaryEvaluationUrn":null},"lss.growth.onboarding.contextual-tooltips-v2-all-tiers":{"trackingInfo":null,"testKey":"lss.growth.onboarding.contextual-tooltips-v2-all-tiers","treatment":"enabled","primaryEvaluationUrn":null},"lss.pages.list-detail.view-in-search-link":{"trackingInfo":null,"testKey":"lss.pages.list-detail.view-in-search-link","treatment":"control","primaryEvaluationUrn":null},"lss.buyer-interest.dashboard.product-category-interest":{"trackingInfo":null,"testKey":"lss.buyer-interest.dashboard.product-category-interest","treatment":"control","primaryEvaluationUrn":null},"lss.pages.save-cta.consistent-experience":{"trackingInfo":null,"testKey":"lss.pages.save-cta.consistent-experience","treatment":"control","primaryEvaluationUrn":null},"lss.profile.useNewRecommendationsApi":{"trackingInfo":null,"testKey":"lss.profile.useNewRecommendationsApi","treatment":"control","primaryEvaluationUrn":null},"lss-lead-page-latest-touch-point":{"trackingInfo":null,"testKey":"lss-lead-page-latest-touch-point","treatment":"enabled","primaryEvaluationUrn":null},"lss.buyer-interest.activities.filters":{"trackingInfo":null,"testKey":"lss.buyer-interest.activities.filters","treatment":"enabled","primaryEvaluationUrn":null},"lss.search.keywords-to-filters.member":{"trackingInfo":null,"testKey":"lss.search.keywords-to-filters.member","treatment":"control","primaryEvaluationUrn":null},"lss.relationship-explorer.member":{"trackingInfo":null,"testKey":"lss.relationship-explorer.member","treatment":"control","primaryEvaluationUrn":null},"lss.search.sub-nav-consistency":{"trackingInfo":null,"testKey":"lss.search.sub-nav-consistency","treatment":"control","primaryEvaluationUrn":null},"lss.ssi.allow-guest-users":{"trackingInfo":null,"testKey":"lss.ssi.allow-guest-users","treatment":"enabled","primaryEvaluationUrn":null},"lss.growth.retry-onboarding":{"trackingInfo":null,"testKey":"lss.growth.retry-onboarding","treatment":"control","primaryEvaluationUrn":null},"lss-search.account-lti-headcount":{"trackingInfo":null,"testKey":"lss-search.account-lti-headcount","treatment":"enabled","primaryEvaluationUrn":null},"lss.hue-infra-migration":{"trackingInfo":null,"testKey":"lss.hue-infra-migration","treatment":"control","primaryEvaluationUrn":null},"lss-desktop-internal-feedback":{"trackingInfo":null,"testKey":"lss-desktop-internal-feedback","treatment":"control","primaryEvaluationUrn":null},"lss.notifications.buyer-activities-aggregation":{"trackingInfo":null,"testKey":"lss.notifications.buyer-activities-aggregation","treatment":"control","primaryEvaluationUrn":null},"lss.pages.circle-of-influence":{"trackingInfo":null,"testKey":"lss.pages.circle-of-influence","treatment":"control","primaryEvaluationUrn":null},"lss.growth.reduced-onboarding-flow":{"trackingInfo":null,"testKey":"lss.growth.reduced-onboarding-flow","treatment":"control","primaryEvaluationUrn":null},"lss.search.saved-label-on-entity-lockup":{"trackingInfo":null,"testKey":"lss.search.saved-label-on-entity-lockup","treatment":"control","primaryEvaluationUrn":null},"lss.pages.new-lead-page.relationship-empty-states-layout":{"trackingInfo":null,"testKey":"lss.pages.new-lead-page.relationship-empty-states-layout","treatment":"enabled","primaryEvaluationUrn":null},"lss.saving_lists_alerts.add_ ...
# <meta content="true" name="isBrowserSupported"/>
# <meta content="true" name="isGuest"/>
# <meta data-mode="VANILLA" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="true" name="isQueryTunnelRequestSupported">
# <link href="https://static.licdn.com/aero-v1/sc/h/5cl1w8eg1kqflbj8pj2m4m476" rel="stylesheet"/>
# <link href="https://static.licdn.com/aero-v1/sc/h/cvhenr2vhe7y2bpx8y1r8jtl1" rel="stylesheet"/>
# <meta content="https://static.licdn.com/aero-v1/sc/h/4upgxfhayj4r4ly3uoyyw46cp" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# </meta></head>
# <body>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <div id="hue-web-menu-outlet"></div>
# <div id="hue-web-modal-outlet"></div>
# <div id="hue-web-tooltip-outlet"></div>
# <div id="hue-web-typeahead-outlet"></div>
# <script crossorigin="" data-fastboot-src="assets/polyfill-shared.js" src="https://static.licdn.com/aero-v1/sc/h/1yylczmz7x5dapxgx5r0jeujt"></script>
# <script crossorigin="" data-fastboot-src="assets/polyfill-legacy.js" nomodule="" src="https://static.licdn.com/aero-v1/sc/h/66viir3qw9l3vz1ln34nhfwfh"></script>
# <script crossorigin="" data-fastboot-src="assets/polyfill-evergreen.js" src="https://static.licdn.com/aero-v1/sc/h/a8q6glm6zvu7gvt3mhab9x3zv"></script>
# <div class="initial-loading-state">
# <div class="initial-load-animation">
# <div class="salesnav-image"></div>
# <div class="loading-bar">
# <div class="blue-bar"></div>
# </div>
# </div>
# </div>
# <script crossorigin="" data-fastboot-src="assets/vendor.js" src="https://static.licdn.com/aero-v1/sc/h/4cylhx4smjiawp037cgxkx1l3"></script>
# <script crossorigin="" data-fastboot-src="/assets/chunk.320.703776aa0f415f06787d.js" src="https://static.licdn.com/aero-v1/sc/h/bcnknqdhdcxaxvdyhx0trkpo"></script>
# <script crossorigin="" data-fastboot-src="/assets/chunk.143.30f0e073b1c88c056da7.js" src="https://static.licdn.com/aero-v1/sc/h/o3hy4fzebuh83s0eo3br6n9y"></script>
# <script crossorigin="" data-fastboot-src="assets/i18n/support_en_US.js" src="https://static.licdn.com/aero-v1/sc/h/d1gbzlv2e6kjqsggtzf2o3nsd"></script>
# <script crossorigin="" data-fastboot-src="assets/lighthouse-web.js" src="https://static.licdn.com/aero-v1/sc/h/9frwyptqeljyjbref786tb62z"></script>
# <div id="artdeco-modal-outlet"></div>
# <!--%SSR_BODY*[]%-->
# <div id="ember-panel-outlet"></div>
# </body></html>

# %%
page_source_2 = BeautifulSoup(driver.page_source)
scrolling()
profiles_2 = page_source_2.find_all('div',class_='artdeco-entity-lockup__title ember-view')
print(profiles_2)
all_profile_url_2 = []
for profile_2 in profiles_2:
    URLs_2 = profile_2.find('a', href =True)
    sales_navigator_2 = (URLs_2['href'])
    #print(sales_navigator)
    doctor_personal_profile = 'https://www.linkedin.com'+ (sales_navigator_2)
    
    if doctor_personal_profile not in all_profile_url_2:
        all_profile_url_2.append(doctor_personal_profile)
        
    print(all_profile_url_2)
URLs_all_page = all_profile_url + all_profile_url_2
sleep(5)
print(URLs_all_page)
print(len(URLs_all_page))
# Out:
# [<div class="artdeco-entity-lockup__title ember-view" id="ember1345">
# <a class="ember-view" data-control-id="X­­ÌÀBKªÑ©=±!" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAACYcrUABg6JwoDKTxYu4rN0bV5mjIPGoZFk,NAME_SEARCH,a8Ck?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D" id="ember1346">
# <span data-anonymize="person-name">Michael Lang</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember1367">
# <a class="ember-view" data-control-id="Ià9¨ßD£»Ï±væÖÝ" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAn3TM4BPn2zwtQXcJEGrp3t8gI_zEC_pEc,NAME_SEARCH,s0gU?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D" id="ember1368">
# <span data-anonymize="person-name">Shandi J Fuller</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember1391">
# <a class="ember-view" data-control-id="Ù7M°ôk®QÍMù" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAA5QnLQBBI-RtMurbgYoBAPav5yzAXvUcFk,NAME_SEARCH,SXRK?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D" id="ember1392">
# <span data-anonymize="person-name">Kamaal Jones</span>
# </a>
# </div>, <div class="artdeco-entity-lockup__title ember-view" id="ember1422">
# <a class="ember-view" data-control-id="EÆú;LºÒÂ.&gt;âwP" data-control-name="view_lead_panel_via_search_lead_name" href="/sales/lead/ACwAAAGfi28Bkm459s3krq7-ssDODLxhOig7KTM,NAME_SEARCH,QzYm?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D" id="ember1423">
# <span data-anonymize="person-name">Jaclyn Richards, MD</span>
# </a>
# </div>]
# ['https://www.linkedin.com/sales/lead/ACwAACYcrUABg6JwoDKTxYu4rN0bV5mjIPGoZFk,NAME_SEARCH,a8Ck?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAACYcrUABg6JwoDKTxYu4rN0bV5mjIPGoZFk,NAME_SEARCH,a8Ck?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAn3TM4BPn2zwtQXcJEGrp3t8gI_zEC_pEc,NAME_SEARCH,s0gU?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAACYcrUABg6JwoDKTxYu4rN0bV5mjIPGoZFk,NAME_SEARCH,a8Ck?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAn3TM4BPn2zwtQXcJEGrp3t8gI_zEC_pEc,NAME_SEARCH,s0gU?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA5QnLQBBI-RtMurbgYoBAPav5yzAXvUcFk,NAME_SEARCH,SXRK?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D']
# ['https://www.linkedin.com/sales/lead/ACwAACYcrUABg6JwoDKTxYu4rN0bV5mjIPGoZFk,NAME_SEARCH,a8Ck?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAn3TM4BPn2zwtQXcJEGrp3t8gI_zEC_pEc,NAME_SEARCH,s0gU?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAA5QnLQBBI-RtMurbgYoBAPav5yzAXvUcFk,NAME_SEARCH,SXRK?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3D', 'https://www.linkedin.com/sales/lead/ACwAAAGfi28Bkm459s3krq7-ssDODLxhOig7KTM,NAME_SEARCH,QzYm?_ntb=RLYQKkswSKW9PU%2FF0S1I%2Fw%3D%3
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    #page_souce = driver.page_source
    page_source = BeautifulSoup(driver.page_source)
    
    #Doctor Name
    doc_name = page_source.find_all('div',class_='_name-title-container_sqh8tm')
    try:
        nam = doc_name[0].find('h1').get_text()
        print(nam)
        doctor_name.append(nam)
        sleep(2)
        
    except:
        no_nam = print('Null')
        doctor_name.append(no_nam)
    
    #Doctor Job
    doc_job = page_source.find_all('div',class_='_lockup-content_p4eb22')
    try:
        employee = doc_job[1].find('p').get_text()
        print(job)
        job_title.append(employee)
        sleep(2)
        
    except:
        no_emp = print('Null')
        job_title.append(no_emp)
        sleep(2)
        
    #Doctor's Address
    doc_location = page_source.find('div',class_='_lockup-caption_sqh8tm _bodyText_1e5nen _default_1i6ulk _sizeSmall_1e5nen _lowEmphasis_1i6ulk').get_text()
    print(doc_location)
    doctor_address.append(doc_location)
    sleep(2)
    
   
    #_contact-info
    doc_mail = page_source.find('span', class_='_secondary-link_hqxetg')
    #mail = persons_mail[0]
    print(doc_mail)
    doctor_mail_web.append(doc_mail)
    sleep(2)
# Out:
#               Michael Lang
#
#
# Deputy Health Officer/Maternal Child Adolescent Health medical Consultant at Solano County
#
#
#
#
#
#               San Francisco Bay Area
#
# None
#
#               Shandi J Fuller
#
#
# Deputy Health Officer/Maternal Child Adolescent Health medical Consultant at Solano County
#
#
#
#
#
#               Concord, California, United States
#
# None
#
#               Kamaal Jones
#
#
# Deputy Health Officer/Maternal Child Adolescent Health medical Consultant at Solano County
#
#
#
#
#
#               Los Angeles, California, United States
#
# <span class="_secondary-link_hqxetg" data-anonymize="remove">
#                     https://twitter.com/doc_KJones
#                 </span>
#
#               Jaclyn Richards, MD
#
#
# Deputy Health Officer/Maternal Child Adolescent Health medical Consultant at Solano County
#
#
#
#
#
#               Los Angeles Metropolitan Area
#
# None

# %%
ucare_page2_doctors = pd.DataFrame({'Name': doctor_name, 'Company':job_title, 'Address':doctor_address, 'Email_Web':doctor_mail_web})
ucare_page2_doctors
# Out:
#                                                  Name  \
# 0                  \n              Yan Chin\n
# 1   \n              Naomi Lawrence-Reid, M.D.\n   ...
# 2   \n              Dimple Khona, MD, MBA, FAAP, I...
# 3         \n              Rina Shah , M. D.\n
# 4             \n              Juan Espinoza\n
# 5    \n              Yvette Drake McLin, MD\n
# 6           \n              David Golergant\n
# 7   \n              Rafael Edmundo Li Jimenez\n   ...
# 8   \n              Christophe Le Renard, M.D., FA...
# 9             \n              Joel Brownell\n
# 10     \n              Ara Balkian, MD, MBA\n
# 11               \n              Dai Le, MD\n
# 12  \n              Vivian Chima Ogueli, MD MBA FA...
# 13            \n              Niranjan Dass\n
# 14  \n              Alberto Betancourt Gutiérrez\n...
# 15    \n              Javier Bustamante, MD\n
# 16           \n              Sabiha Hussain\n
# 17         \n              Steven Abelowitz\n
# 18  \n              Paul Lukac, MD, MBA, MS\n
# 19              \n              Noel Torres\n
# 20  \n              R. Ryan Sadeghian, MD, MBA, MS...
# 21            \n            LinkedIn Member\n
# 22   \n              Keri Carstairs, MD MBA\n
# 23             \n              Michael Lang\n
# 24          \n              Shandi J Fuller\n
# 25          \n              Shandi J Fuller\n
# 26             \n              Michael Lang\n
# 27          \n              Shandi J Fuller\n
# 28             \n              Kamaal Jones\n
# 29      \n              Jaclyn Richards, MD\n
#
#                                               Company  \
# 0   \n                        Private Medical\n   ...
# 1   \nPhysician Master Trainer at Veteran Medical ...
# 2   \nPediatric Hospital Medicine Subboard Member ...
# 3   \nBoard Member at Hill Physicians Medical Grou...
# 4   \nDirector, Principal Investigator at Consorti...
# 5   \n                        Kaiser Permanente\n ...
# 6   \n                        Adventist Health\n  ...
# 7   \n                        Facey Medical Founda...
# 8   \nChief Medical Information Officer at Cottage...
# 9   \nPediatrician at Childrens Hospital Central C...
# 10  \nChief Medical Director, Inpatient Operations...
# 11  \n                        Antelope Valley Medi...
# 12  \nPediatrician, Urgent Care at St. Joseph Heal...
# 13  \nMD, FAAP, ACE-Trainer at Redbluff Rancheria ...
# 14  \n                        neonatologos de sucr...
# 15  \nPresident and Senior Partner at Live Office ...
# 16  \n                        Scripps Health\n    ...
# 17               \nBusiness Owner at Coastal Kids\n\n
# 18  \nEditorial Board Member at Journal of America...
# 19  \nPhysician-Pediatrician at AltaMed Health Ser...
# 20  \nAttending Physician - General Pediatrician a...
# 21                                               None
# 22  \nChief Population Health Officer at Rady Chil...
# 23  \nAssociate Chief Medical Information Officer,...
# 24  \nDeputy Health Officer/Maternal Child Adolesc...
# 25  \nDeputy Health Officer/Maternal Child Adolesc...
# 26  \nAssociate Chief Medical Information Officer,...
# 27  \nDeputy Health Officer/Maternal Child Adolesc...
# 28  \n                        Los Angeles County D...
# 29  \n                        Family Health Care C...
#
#                                               Address  \
# 0   [\n, [\n, [], \n], \n              San Francis...
# 1   [\n, [\n, [], \n], \n              San Diego, ...
# 2   [\n, [\n, [], \n], \n              Yorba Linda...
# 3   [\n, [\n, [], \n], \n              Walnut Cree...
# 4   [\n, [\n, [], \n], \n              Los Angeles...
# 5   [\n, [\n, [], \n], \n              Los Angeles...
# 6   [\n, [\n, [], \n], \n              United Stat...
# 7   [\n, [\n, [], \n], \n              Los Angeles...
# 8   [\n, [\n, [], \n], \n              Santa Barba...
# 9   [\n, [\n, [], \n], \n              Fresno, Cal...
# 10  [\n, [\n, [], \n], \n              Los Angeles...
# 11  [\n, [\n, [], \n], \n              Lancaster, ...
# 12  [\n, [\n, [], \n], \n              Orange, Cal...
# 13  [\n, [\n, [], \n], \n              Bakersfield...
# 14  [\n, [\n, [], \n], \n              Santa Monic...
# 15  [\n, [\n, [], \n], \n              Bakersfield...
# 16  [\n, [\n, [], \n], \n              San Diego, ...
# 17  [\n, [\n, [], \n], \n              United Stat...
# 18  [\n, [\n, [], \n], \n              Santa Monic...
# 19  [\n, [\n, [], \n], \n              Los Angeles...
# 20  [\n, [\n, [], \n], \n              Los Angeles...
# 21  [\n, [\n, [], \n], \n              Pasadena, C...
# 22  [\n, [\n, [], \n], \n              Rancho Sant...
# 23  [\n, [\n, [], \n], \n              San Francis...
# 24  [\n, [\n, [], \n], \n              Concord, Ca...
# 25  \n\n\n\n              Concord, California, Uni...
# 26  \n\n\n\n              San Francisco Bay Area\n...
# 27  \n\n\n\n              Concord, California, Uni...
# 28  \n\n\n\n              Los Angeles, California,...
# 29  \n\n\n\n              Los Angeles Metropolitan...
#
#                                             Email_Web
# 0                                                None
# 1   [\n                    www.doctoringdifferentl...
# 2                                                None
# 3                                                None
# 4   [\n                    www.westcoastctip.org\n...
# 5                                                None
# 6   [\n                    http://www.drgolergant....
# 7                                                None
# 8                                                None
# 9                                                None
# 10  [\n                    http://www.chla.org/sit...
# 11                                               None
# 12                                               None
# 13  [\n                    http://NiranjanMD-Dolen...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  [\n                    www.ryansadeghian.com\n...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28  [\n                    https://twitter.com/doc...
# 29                                               None

# %% [markdown]
# # URLs of Profiles, Accessibility

# %%
from time import sleep

#def GetURL():
    #Doctor Profile Extraction
    #Write a code to extract the name of one page
    #from time import sleep
    
time.sleep(3)    


#previous_height = driver.execute_script('return document.body.scrollHeight') 
previous_height = driver.find_element_by_tag_name('body')
scroll_hoja = previous_height.send_keys(Keys.PAGE_DOWN)

for i in range(10):
    while True:
        (i, scroll_hoja)

        #previous_height.send_keys(Keys.PAGE_DOWN)
        time.sleep(3)
    
        new_height = driver.execute_script('return document.body.scrollHeight')
        sleep(1)
   
        if new_height == scroll_hoja:
            break
        scroll_hoja = new_height
    
#driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')  
#previous_height = driver.find_element_by_tag_name('body')
#previous_height.send_keys(Keys.PAGE_DOWN)

"""
while True:
    previous_height.send_keys(Keys.PAGE_DOWN)
    time.sleep(3)
    
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == previous_height:
        break
    previous_height = new_height

scroll = driver.find_element_by_tag_name('body')
scroll_down = scroll.send_keys(Keys.PAGE_DOWN)
scroll_down
time.sleep(1)
"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12032\2444456792.py in <module>
#      10
#      11 #previous_height = driver.execute_script('return document.body.scrollHeight')
# ---> 12 previous_height = driver.find_element_by_tag_name('body')
#      13 scroll_hoja = previous_height.send_keys(Keys.PAGE_DOWN)
#      14
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_tag_name'

# %%
page_source = BeautifulSoup(driver.page_source)
time.sleep(3)

#driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')



profiles = page_source.find_all('div',class_='artdeco-entity-lockup__title ember-view')
print(profiles)
time.sleep(3)

#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

all_profile_url = []
for profile in profiles:
    URLs = profile.find('a', href =True)
    sales_navigator = (URLs['href'])
    #print(sales_navigator)
    doc_personal_profile = 'https://www.linkedin.com'+ (sales_navigator)
    
    if doc_personal_profile not in all_profile_url:
        all_profile_url.append(doc_personal_profile)
    
    
    #return all_profile_url
    print(all_profile_url)
#print(GetURL())

length = len(all_profile_url)
print(length)

# %% [markdown]
# # Pagination Stuff, To get URLs of All Pages

# %%
from time import sleep

#def GetURLsonpages():
input_page = int(input('pages you wanna scrap?'))
URLs_all_page = []

for page in range(input_page):
    sleep(3)
    URL_one_page = GetURL()
    sleep(10)
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    #Above Scroll Down Till not working according to our requirements
    sleep(3)
        
    next_button = driver.find_element_by_class_name("artdeco-pagination__button--next")
    next_button.click()
    sleep(3)
        
    #Getting URLs for all pages
    URLs_all_page = URLs_all_page + URL_one_page
    sleep(5)
    #return URLs_all_page
    print(URLs_all_page)
#print(GetURLsonpages())

# %% [markdown]
# # Data Extraction

# %%
from time import sleep

#overall_data = GetURLsonpages()
for linkedIn_url in URLs_all_page:
    driver.get(linkedIn_url)
    sleep(2)
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    #page_souce = driver.page_source
    page_source = BeautifulSoup(driver.page_source)
    
    
    person_name = page_source.find_all('div',class_='_name-title-container_sqh8tm')
    name = person_name[0].find('h1').get_text()
    print(name)
    sleep(2)
    
    person_job = page_source.find_all('div',class_='_bodyText_1e5nen _default_1i6ulk')
    job = person_job[0].find('span').get_text()
    print(job)
    sleep(2)
    
    person_location = page_source.find('div',class_='_lockup-caption_sqh8tm _bodyText_1e5nen _default_1i6ulk _sizeSmall_1e5nen _lowEmphasis_1i6ulk').get_text()
    print(person_location)
    sleep(2)
    
    person_mail = page_source.find_all('div',class_='_layout_hqxetg _column_hqxetg _grid_17ha7o _gap-none_17ha7o')
    mail = person_mail[0].find('a', href =True)
    persons_mail = mail[0]['href']
    print(persons_mail)
    sleep(2)

# %%
from time import sleep
#page_source = BeautifulSoup(driver.page_source)

page_source = BeautifulSoup(driver.page_source)
sleep(3)

person_mail = page_source.find_all('div',class_='_layout_hqxetg _column_hqxetg _grid_17ha7o _gap-none_17ha7o')
mail = person_mail[0].find('a', href =True)
persons_mail = (mail['href'])
print(persons_mail)
# Out:
# http://ADAMacon.com

# %%
#Write a code to extract the name of one page
from time import sleep
page_source = BeautifulSoup(driver.page_source)
sleep(3)

person_name = page_source.find_all('div',class_='_name-title-container_sqh8tm')

name = person_name[0].find('h1').get_text()
print(name)
# Out:
#               Samer Othman

# %%
#Write a code to extract the name of the company
from time import sleep
page_source = BeautifulSoup(driver.page_source)
sleep(3)

person_job = page_source.find_all('div',class_='_bodyText_1e5nen _default_1i6ulk')

job = person_job[0].find('span').get_text()
print(job)
# Out:
# Dentist and Owner - Advanced Dental Arts, LLC

# %%
#Write a code to extract the Address or Location
from time import sleep
page_source = BeautifulSoup(driver.page_source)
sleep(3)

person_location = page_source.find('div',class_='_lockup-caption_sqh8tm _bodyText_1e5nen _default_1i6ulk _sizeSmall_1e5nen _lowEmphasis_1i6ulk').get_text()

#name = person_location[0].find('svg').get_text()
print(person_location)
# Out:
#               Greater Macon

# %%
# Contact Info Icon In persons Profile
#page_souce = driver.page_source


from time import sleep
page_source = BeautifulSoup(driver.page_source)
sleep(3)
#print(page_source)


info_title = driver.find_element_by_class_name('_text_ddl063 _text_ps32ck')
info_title.click() 

#info_icon.click()

#//*[@id="ember67"]/span
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9676\2454179022.py in <module>
#       7
#       8
# ----> 9 info_title = driver.find_element_by_class_name('_text_ddl063 _text_ps32ck')
#      10 #info_title.click()
#      11
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\kr\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"._text_ddl063 _text_ps32ck"}
#   (Session info: chrome=106.0.5249.119)
