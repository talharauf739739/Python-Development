# %%
  # !pip install nltk
  import nltk
  nltk.download('punkt')
  nltk.download('stopwords')
  from nltk.corpus import wordnet as wn
  import sklearn
  import os
  import re
  import pandas as pd
  import math
  import collections as cl
  import scipy as sp
  import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install textract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 KB 5.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 KB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 57.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 110.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 120.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 105.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 15.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import textract
text = textract.process('/content/doctors.pdf', method='pdfminer')
text
# Out:
# b"First\n\nLast\n\nDegree(s)\n\nProfession\n\nCountry\n\nState\n\nCity\n\nPhone\n\nEmail\n\nWebsite\n\nYrs in Practice Yrs in CBTI CBSM Certified\n\nUniversity Affiliation?\n\nSleep DO Ctr. Affiliation?\n\nH.\n\nMitchell\n\nClinical Psychologist\n\nBirmingham\n\n205-879-0202\n\nhdixonmitchell@gmail.com www.dixonmitchell.net\n\nPlanned\n\n30\n\n4\n\nWilliam\n\nBryson\n\nClinical Psychologist\n\nHunsville\n\n(256) 533-9393\n\nKenneth\n\nLichstein\n\nPHD, CBSM\n\nClinical Psychlogist\n\nTuscaloosa\n\n(205) 348-4962\n\nArlene\n\nSullivan\n\nMNSc, APRN\n\nNurse Practitioner\n\nLittle Rock\n\n501-202-1902\n\narsullivan@practice-\n\nplus.com\n\nRobert \n\nBoyle\n\nPHD\n\nClinical Health Psychologist\n\nUSA\n\nSherwood\n\n501-771-4442\n\nARBMS@ARBMS.org\n\nwww.ARBMS.com\n\n602-277-5551 ext \n\nPhoenix\n\n17725\n\ndana.epstein@va.gov\n\nScottsdale\n\n(480) 467-0300\n\nPHD, RN, CT, \nNCC, AHN-BC, \n\nFAAN\n\nMD, CBSM\nPHD, RN, CT, \nNCC, AHN-BC, \n\nFAAN\n\nNurse\n\nPhysician\n\nDana\n\nEpstei
# ...

# %%
#!pip install re
import re
#line = "should we use regex more often? let me know at  jdsk@bob.com.lol"
#mails = re.findall(r'[\w.+-]+@[\w-]+\.[\w.-]+', text)
#mails
emails = []
import re

#my_bytes = b'apple,banana,kiwi'

mails = re.findall('[\w.+-]+@[\w-]+\.[\w.-]+', text.decode('utf-8'))

for mail in mails:
  emails.append(mail)
print(mails[0])  # 👉️ <re.Match object; span=(0, 5), match='apple'>
emails
#emails.append(mails)
# Out:
# hdixonmitchell@gmail.com
# ['hdixonmitchell@gmail.com',
#  'ARBMS@ARBMS.org',
#  'dana.epstein@va.gov',
#  'carol.baldwin@asu.edu',
#  'jbecker@ucla.edu',
#  'drbrass@drestherbrass.co',
#  'kathybeckerman@aol.com',
#  'j.young@ucla.edu',
#  'TracyKuoPhd@gmail.com',
#  'Info@DrCarrCBT.com',
#  'karen.munoz.phd@gmail.c',
#  'DPlotkin@mednet.ucla.ed',
#  'Jemartin@ucla.edu',
#  'katekaplanphd@gmail.com',
#  'lisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'penbh.comlisa@penbh.comlisa',
#  'DRMSTEVE@AOL.COM',
#  'ghartell@gmail.com',
#  'dryeilding@gmail.com',
#  'DrRichardBarth@gmail.co',
#  'mat@sfbacct.com',
#  'dw@sfbacct.com',
#  'dposner57@gmail.com',
# ...

# %%
       # dictionary
Phycisians = pd.DataFrame({'EMAIL': emails})

Phycisians
# Out:
#                                                  EMAIL
# 0                             hdixonmitchell@gmail.com
# 1                                      ARBMS@ARBMS.org
# 2                                  dana.epstein@va.gov
# 3                                carol.baldwin@asu.edu
# 4                                     jbecker@ucla.edu
# ..                                                 ...
# 362                            xiaofand@seas.upenn.edu
# 363                    efriedman@texassleeptherapy.com
# 364  meredith@balancedandwell.orgwww.balancedandwel...
# 365                               orski.Allan@mayo.edu
# 366                                shun.nkjm@gmail.com
#
# [367 rows x 1 columns]

# %%
Phycisians.to_excel('Phycisians_mails.xlsx', index=False)
